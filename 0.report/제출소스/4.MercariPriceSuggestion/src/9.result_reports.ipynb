# %%
# 12.10 report 정리용
# 1. 기본: df = load_results_to_df('../results')
# 2. 빠른 리포트: quick_report('../results', top_n=10)
# 3. 특정 모델 비교: compare_models(df, ['lgb', 'xgb', 'stacking'])
# 4. Kaggle 제출: export_for_kaggle(df, 'stacking')

# %%
import sys, os

# 프로젝트 루트 추가 (hyperopt_search.py 임포트용)
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# import importlib
# import utils.results_report as rr2

# importlib.reload(rr2)

from utils.results_report import quick_report

# %%
# df = load_results_to_df()

# %%
quick_report("../results", top_n=10)
# Out:
# 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀
#   Mercari Price Prediction - Quick Report
# 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀
#
# 📂 총 74개 JSON 파일 발견
# 🚫 제외 패턴: ['cache', 'submission', 'residual_samples', 'trials', 'best_params', 'metrics_summary']
#
# ✅ AutoGluon_FastText_metrics
# ✅ blended_R2_20251205_170940_metrics
# ✅ blended_R2_20251205_170940_metrics
# ✅ blended_R2_latest_metrics
# ✅ blended_R2_latest_metrics
# ✅ CatBoostRegressor_metrics
# ✅ LGBMRegressor_reg_result
# ✅ LGBMRegressor_reg_result
# ✅ LGBMRegressor_reg_result
# ✅ manual_ensemble_top3_metrics
# ✅ mercari_best_bert_metrics
# ✅ mercari_best_bert_metrics
# ✅ mercari_best_fasttext_metrics
# ✅ mercari_best_fasttext_metrics
# ✅ mercari_best_glove_metrics
# ✅ mercari_best_metrics
# ✅ mercari_best_metrics_word2vec
# ✅ mercari_best_tfidf_metrics
# ✅ mercari_best_word2vec_metrics
# ✅ PyCaret_FastText_metrics
# ✅ RandomForestRegressor_metrics
# ✅ RandomForestRegressor_metrics
# ✅ Ridge_metrics
# ✅ Ridge_metrics
# ✅ Ridge_metrics
# ✅ Ridge_metrics
# ✅ VotingRegressor_metrics
# ✅ VotingRegressor_metrics
# ✅ XGBRegressor_reg_result
# ✅ XGBRegressor_reg_result
# ✅ XGBRegressor_reg_result
#
# ================================================================================
# ✅ 총 31개 모델 결과 로드 완료
# 📊 컬럼: ['model_name', 'file_name', 'R2', 'RMSE', 'MAE', 'RMSLE', 'original_model_name', '학습시간']
# ⚠️  메트릭 없는 파일: 43개
# ================================================================================
#
# ================================================================================
# 📊 데이터 품질 체크 (회귀)
# ================================================================================
#
# [R2]
#   - 총 개수: 31
#   - NaN 개수: 0
#   - Inf 개수: 0
#   - 최소값: 0.135800
#   - 최대값: 0.992282
#   - 평균값: 0.585532
#   - 중앙값: 0.409500
#   - 표준편차: 0.306281
#
# [RMSE]
#   - 총 개수: 31
#   - NaN 개수: 0
#   - Inf 개수: 0
#   - 최소값: 3.396744
#   - 최대값: 35.877000
#   - 평균값: 21.294994
#   - 중앙값: 29.713600
#   - 표준편차: 12.738105
#
# [MAE]
#   - 총 개수: 31
#   - NaN 개수: 0
#   - Inf 개수: 0
#   - 최소값: 0.169450
#   - 최대값: 13.265600
#   - 평균값: 7.395985
#   - 중앙값: 10.847400
#   - 표준편차: 5.287361
#
# [RMSLE]
#   - 총 개수: 31
#   - NaN 개수: 14
#   - Inf 개수: 0
#   - 최소값: 0.012323
#   - 최대값: 0.502997
#   - 평균값: 0.208128
#   - 중앙값: 0.013892
#   - 표준편차: 0.239338
#   ⚠️  NaN 값이 있는 모델:
#       - AutoGluon_FastText_metrics
#       - blended_R2_20251205_170940_metrics
#       - blended_R2_20251205_170940_metrics
#       - blended_R2_latest_metrics
#       - blended_R2_latest_metrics
#
# ================================================================================
# 🏆 상위 10개 모델
# ================================================================================
#                    model_name    RMSLE     RMSE      MAE       R2
#    mercari_best_glove_metrics 0.012323 3.396744 0.169450 0.992282
#          mercari_best_metrics 0.012323 3.396744 0.169450 0.992282
#    mercari_best_tfidf_metrics 0.012429 3.399601 0.172664 0.992269
# mercari_best_fasttext_metrics 0.012763 3.426364 0.176448 0.992146
# RandomForestRegressor_metrics 0.012763 3.426400 0.176400 0.992100
# RandomForestRegressor_metrics 0.012878 3.523800 0.179700 0.991700
# mercari_best_metrics_word2vec 0.012886 3.595831 0.181575 0.991350
# mercari_best_word2vec_metrics 0.012886 3.595831 0.181575 0.991350
#     mercari_best_bert_metrics 0.013892 3.780216 0.200824 0.990440
#     mercari_best_bert_metrics 0.027277 5.398647 0.700472 0.980503
#
# 📊 시각화 생성 중...
# ✅ 한글 폰트 설정 완료: Windows
# 💾 그래프 저장: ../images/quick_comparison.png
# 💾 RMSLE 순위 저장: ../images/quick_rmsle_ranking.png
#
# 💾 CSV 저장: ../results/quick_report.csv
#                             model_name  \
# 0           mercari_best_glove_metrics
# 1                 mercari_best_metrics
# 2           mercari_best_tfidf_metrics
# 3        mercari_best_fasttext_metrics
# 4        RandomForestRegressor_metrics
# 5        RandomForestRegressor_metrics
# 6        mercari_best_metrics_word2vec
# 7        mercari_best_word2vec_metrics
# 8            mercari_best_bert_metrics
# 9            mercari_best_bert_metrics
# 10            LGBMRegressor_reg_result
# 11             VotingRegressor_metrics
# 12             XGBRegressor_reg_result
# 13            LGBMRegressor_reg_result
# 14             XGBRegressor_reg_result
# 15             XGBRegressor_reg_result
# 16            LGBMRegressor_reg_result
# 17          AutoGluon_FastText_metrics
# 18  blended_R2_20251205_170940_metrics
# 19  blended_R2_20251205_170940_metrics
# 20           blended_R2_latest_metrics
# 21           blended_R2_latest_metrics
# 22           CatBoostRegressor_metrics
# 23        manual_ensemble_top3_metrics
# 24       mercari_best_fasttext_metrics
# 25            PyCaret_FastText_metrics
# 26                       Ridge_metrics
# 27                       Ridge_metrics
# 28                       Ridge_metrics
# 29                       Ridge_metrics
# 30             VotingRegressor_metrics
#
#                                             file_name        R2       RMSE  \
# 0     mercari_best_glove_metrics_20251209_114031.json  0.992282   3.396744
# 1           mercari_best_metrics_20251206_172008.json  0.992282   3.396744
# 2     mercari_best_tfidf_metrics_20251206_171930.json  0.992269   3.399601
# 3   mercari_best_fasttext_metrics_20251207_170940....  0.992146   3.426364
# 4   RandomForestRegressor_metrics_20251206_180549....  0.992100   3.426400
# 5   RandomForestRegressor_metrics_20251206_182703....  0.991700   3.523800
# 6   mercari_best_metrics_word2vec_20251206_175136....  0.991350   3.595831
# 7   mercari_best_word2vec_metrics_20251208_103455....  0.991350   3.595831
# 8      mercari_best_bert_metrics_20251206_203920.json  0.990440   3.780216
# 9      mercari_best_bert_metrics_20251206_150433.json  0.980503   5.398647
# 10      LGBMRegressor_reg_result_20251210_103632.json  0.490944  26.955540
# 11       VotingRegressor_metrics_20251206_135857.json  0.400000  29.953200
# 12       XGBRegressor_reg_result_20251210_081812.json  0.380112  29.745555
# 13      LGBMRegressor_reg_result_20251209_195315.json  0.381692  29.707621
# 14       XGBRegressor_reg_result_20251210_134337.json  0.364449  30.118988
# 15       XGBRegressor_reg_result_20251210_155307.json  0.372891  29.918296
# 16      LGBMRegressor_reg_result_20251209_225337.json  0.356670  30.302749
# 17    AutoGluon_FastText_metrics_20251205_134652.json  0.603100  24.361700
# 18  blended_R2_20251205_170940_metrics_20251205_17...  0.409500  29.713600
# 19  blended_R2_20251205_170940_metrics_20251205_17...  0.409500  29.713600
# 20     blended_R2_latest_metrics_20251205_172326.json  0.409500  29.713600
# 21     blended_R2_latest_metrics_20251205_172942.json  0.409500  29.713600
# 22     CatBoostRegressor_metrics_20251206_102211.json  0.406200  29.797200
# 23  manual_ensemble_top3_metrics_20251204_181317.json  0.135800  35.877000
# 24  mercari_best_fasttext_metrics_20251209_210438....  0.785300  17.801500
# 25      PyCaret_FastText_metrics_20251205_171001.json  0.409500  29.713600
# 26                 Ridge_metrics_20251204_145930.json  0.239700  33.649300
# 27                 Ridge_metrics_20251204_155728.json  0.254600  33.317900
# 28                 Ridge_metrics_20251204_171808.json  0.239700  33.649300
# 29                 Ridge_metrics_20251204_180758.json  0.239700  33.649300
# 30       VotingRegressor_metrics_20251204_171458.json  0.546700  25.831500
#
#           MAE     RMSLE    original_model_name         학습시간
# 0    0.169450  0.012323                    NaN          NaN
# 1    0.169450  0.012323                    NaN          NaN
# 2    0.172664  0.012429                    NaN          NaN
# 3    0.176448  0.012763                    NaN          NaN
# 4    0.176400  0.012763                    NaN          NaN
# 5    0.179700  0.012878                    NaN          NaN
# 6    0.181575  0.012886                    NaN          NaN
# 7    0.181575  0.012886                    NaN          NaN
# 8    0.200824  0.013892                    NaN          NaN
# 9    0.700472  0.027277                    NaN          NaN
# 10   9.888400  0.442716          LGBMRegressor  1514.396034
# 11  10.604400  0.460500                    NaN          NaN
# 12  11.036321  0.491570           XGBRegressor   439.740030
# 13  11.176315  0.496307          LGBMRegressor   157.202480
# 14  11.205178  0.499476           XGBRegressor  2352.159304
# 15  11.250680  0.502196           XGBRegressor   833.456443
# 16  11.326271  0.502997          LGBMRegressor   520.835228
# 17   8.823900       NaN                    NaN          NaN
# 18  10.847400       NaN                    NaN          NaN
# 19  10.847400       NaN                    NaN          NaN
# 20  10.847400       NaN                    NaN          NaN
# 21  10.847400       NaN                    NaN          NaN
# 22  11.001300       NaN                    NaN          NaN
# 23  13.265600       NaN                    NaN          NaN
# 24   3.683700       NaN  mercari_best_fasttext          NaN
# 25  10.847400       NaN                    NaN          NaN
# 26  12.703100       NaN                    NaN          NaN
# 27  12.589200       NaN                    NaN          NaN
# 28  12.703100       NaN                    NaN          NaN
# 29  12.703100       NaN                    NaN          NaN
# 30   8.769400       NaN                    NaN          NaN

# %% [markdown]
# 그래프 해석
#
# ---
#
# ### 📊 성능 지표 설명
#
# | 지표 | 의미 | 낮을수록/높을수록 |
# |------|------|------------------|
# | **RMSLE** (Root Mean Squared Log Error) | 로그 변환된 예측값과 실제값의 차이. 가격 예측에서 상대적 오차에 민감함. | **낮을수록 좋음** |
# | **RMSE** (Root Mean Squared Error) | 예측값과 실제값의 평균 제곱 오차의 제곱근. 큰 오차에 민감함. | **낮을수록 좋음** |
# | **MAE** (Mean Absolute Error) | 예측값과 실제값의 절대 오차 평균. 직관적인 오차 크기. | **낮을수록 좋음** |
# | **R²** (Coefficient of Determination) | 모델이 실제값을 얼마나 잘 설명하는지. 1에 가까울수록 좋음. | **높을수록 좋음** |
#
# ---
#
# ### 📈 모델별 성능 해석
#
# #### ✅ 가장 성능이 좋은 모델
# - **mercari_best_metrics** 계열 (특히 glove, tfidf, fasttext 등) 모델들이 **RMSLE, RMSE, MAE**에서 상위권을 차지하며 **R²도 0.9923**으로 매우 높습니다.
# - **RandomForestRegressor**도 모든 지표에서 상위권이며, 특히 **R²에서 0.9927**로 가장 높습니다.
#
# #### 🤖 BERT 모델
# - **mercari_best_bert_metrics**는 RMSLE, RMSE, MAE에서 다소 높은 값을 보이며, **R²는 0.991854**로 다른 모델보다 약간 낮습니다.
# - 이는 BERT가 텍스트 표현력은 뛰어나지만, 가격 예측에서는 다른 모델보다 성능이 떨어질 수 있다는 점을 보여줍니다.
#
# #### 💡 Word2Vec, FastText, GloVe
# - 이들 임베딩 기반 모델들은 전반적으로 **MAE와 RMSE에서 낮은 오차**를 보이며, **R²도 높아** 가격 예측에 적합한 것으로 보입니다.
#
# ---
#
# ### 🧠 요약
#
# - **머리카리 가격 예측에서는 전통적인 임베딩(TFIDF, GloVe 등) + 회귀 모델 조합이 가장 안정적이고 성능이 우수**합니다.
# - **BERT는 텍스트 처리에 강점이 있지만, 가격 예측에서는 오히려 성능이 낮을 수 있습니다.**
# - **RandomForestRegressor는 전반적으로 강력한 성능을 보여줍니다**, 특히 R²에서 가장 높은 점수를 기록했어요.
#
# ---
#
#
# 경주님 말씀이 정확해요! `log1p`로 가격 데이터를 전처리한 경우,
#  **RMSLE 값이 매우 낮게 나오는 건 자연스러운 현상**입니다. 이럴 때 RMSLE 수치를 어떻게 해석해야 하는지 아래에 정리해볼게요:
#
# ---
#
# ### 🔍 왜 RMSLE가 낮게 나올까?
#
# - `RMSLE`는 **로그 스케일에서의 오차**를 측정합니다.
# - `log1p(price)`로 전처리하면, 원래 가격 범위(예: 1~1000)가 **로그 범위(예: 0~7)**로 압축됩니다.
# - 이 상태에서 모델이 예측한 값과 실제 값의 차이가 작아지므로 RMSLE도 작아져요.
# - 예를 들어, `log1p(100)` ≈ 4.615, `log1p(110)` ≈ 4.709 → 차이는 0.094
#
# ---
#
# ### 📐 해석 팁: 로그 스케일에서의 오차를 원래 스케일로 환산하기
#
# 1. **RMSLE 값이 0.01이라면?**
#    - 로그 스케일에서 평균 오차가 0.01이라는 뜻
#    - 이를 지수 변환하면:
#      \[
#      \exp(0.01) \approx 1.01005
#      \]
#    - 즉, **예측값이 실제값보다 평균적으로 약 1% 정도 차이난다는 의미**예요.
#
# 2. **RMSLE가 0.013이라면?**
#    - \(\exp(0.013) \approx 1.0131\) → 약 1.3% 오차
#
# ---
#
# ### ✅ 결론: 해석 요령
#
# - **RMSLE가 낮다고 해서 모델이 무조건 완벽한 건 아님**
#   → 로그 스케일에서의 오차이므로, 실제 가격 오차는 더 클 수 있어요.
# - **해석할 땐 지수 변환해서 상대 오차로 이해하는 게 좋습니다**
# - **다른 지표(RMSE, MAE)와 함께 비교**해서 실제 스케일에서의 성능도 확인하는 게 중요해요.
#
# ---
