# %%
import pandas as pd
df = pd.read_csv("../data/train.tsv", sep="\t")
print(df.shape)
print(df.columns)
# Out:
# (1482535, 8)
# Index(['train_id', 'name', 'item_condition_id', 'category_name', 'brand_name',
#        'price', 'shipping', 'item_description'],
#       dtype='object')

# %%
del df

# %%
import pickle
with open("../results/cache/mercari_preprocessed_tfidf.pkl","rb") as f:
    a=pickle.load(f)
a[2][:10], a[3][:10]   # y_train, y_valid
# Out:
# (array([2.56494936, 3.13549422, 2.39789527, 2.77258872, 3.4339872 ,
#         3.40119738, 3.58351894, 2.07944154, 3.95124372, 2.48490665]),
#  array([2.56494936, 2.30258509, 3.76120012, 2.77258872, 4.49980967,
#         2.39789527, 2.94443898, 2.83321334, 2.63905733, 3.4657359 ]))
