# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from utils import modeling

# %%
result_dict = {
    'rawdata_catboost':{'AUC': 0.9794, '정확도': 0.9993, '정밀도': 0.7778, '재현율': 0.8571, 'F1': 0.8155},
    'rawdata_dt':{'AUC': 0.9889, '정확도': 0.9992, '정밀도': 0.7350, '재현율': 0.8776, 'F1': 0.8000},
    'rawdata_gb':{'AUC': 0.3469, '정확도': 0.9983, '정밀도': 0.5294, '재현율': 0.1837, 'F1': 0.2727},
    'rawdata_mlp':{'AUC': 0.9580, '정확도': 0.9995, '정밀도': 0.8876, '재현율': 0.8061, 'F1': 0.8449},
    'capped_catboost':{'AUC': 0.9889, '정확도': 0.9992, '정밀도': 0.7350, '재현율': 0.8776, 'F1': 0.8000},
    'capped_dt':{'AUC': 0.9129, '정확도': 0.9990, '정밀도': 0.6750, '재현율': 0.8265, 'F1': 0.7431},
    'capped_gb':{'AUC': 0.9871, '정확도': 0.9990, '정밀도': 0.6587, '재현율': 0.8469, 'F1': 0.7411},
    'capped_lr':{'AUC': 0.9892, '정확도': 0.9683, '정밀도': 0.0486, '재현율': 0.9388, 'F1': 0.0924},
    'capped_mlp':{'AUC': 0.9737, '정확도': 0.9994, '정밀도': 0.8367, '재현율': 0.8367, 'F1': 0.8367},
    'over_capped_catboost':{'AUC': 1.0000, '정확도': 0.9995, '정밀도': 0.9991, '재현율': 1.0000, 'F1': 0.9995},
    'over_capped_dt':{'AUC': 0.9982, '정확도': 0.9983, '정밀도': 0.9975, '재현율': 0.9990, 'F1': 0.9983},
    'over_capped_gb':{'AUC': 0.9985, '정확도': 0.9788, '정밀도': 0.9863, '재현율': 0.9713, 'F1': 0.9787},
    'over_capped_mlp':{'AUC': 1.0000, '정확도': 0.9997, '정밀도': 0.9994, '재현율': 1.0000, 'F1': 0.9997},
    'und_capped_catboost':{'AUC': 0.9736, '정확도': 0.9239, '정밀도': 0.9663, '재현율': 0.8776, 'F1': 0.9198},
    'und_capped_dt':{'AUC': 0.8882, '정확도': 0.8883, '정밀도': 0.9130, '재현율': 0.8571, 'F1': 0.8842},
    'und_capped_gb':{'AUC': 0.9767, '정확도': 0.9289, '정밀도': 0.9565, '재현율': 0.8980, 'F1': 0.9263},
    'und_capped_mlp':{'AUC': 0.9774, '정확도': 0.9391, '정밀도': 0.9574, '재현율': 0.9184, 'F1': 0.9375}
}

# %%
modeling.plot_sampling_metrics(result_dict,title='데이터 전처리 요약')
# Out:
# 📁 그래프 저장 완료: ..\images\데이터 전처리 요약_2025_1128.png
