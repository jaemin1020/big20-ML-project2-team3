# %%
import sys

project_root = 'c:/big20/git/big20-ML-project2-team3/CreditCardFraud'

# sys.path에 추가 (모듈 import용)
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from utils.results_report  import load_results_to_df

# %%
df_results = load_results_to_df('../results', sort_by='F1', ascending=False)

if not df_results.empty:
    # 중복 모델명 확인
    duplicates = df_results[df_results.duplicated('model_name', keep=False)]
    if not duplicates.empty:
        print("\n⚠️  중복된 모델명 발견:")
        print(duplicates[['model_name', 'file_name']].to_string(index=False))
    
    # 상위 10개 출력
    print("\n📈 F1 점수 상위 10개 모델:")
    top_cols = ['model_name', 'AUC', 'F1', 'F2', '정밀도', '재현율']
    available_cols = [col for col in top_cols if col in df_results.columns]
    print(df_results[available_cols].head(10).to_string(index=False))
# Out:
# 📂 154개 파일 발견. 처리 중...
#
# ✅  DecisionTree_notscaled_Timedrop
# ✅  GradientBoosting_notscaled_Timedrop
# ❌ JSON 파싱 오류:  MLP_notscaled_Timedrop__2025_11_27_20251127.txt
# ✅ capped_data_catboost_20251126
# ✅ capped_data_dt_20251126
# ✅ capped_data_gb_20251126
# ✅ capped_data_lr_20251126
# ✅ capped_data_mlp_20251126
# ❌ JSON 파싱 오류: cb+xgb+lgbm+gb_ho-best_20251201.txt
# ✅ cb_ho_best
# ✅ cb_ho_best
# ✅ cb_ho_best_ejm
# ✅ DecisionTree_Amount_Timedrop
# ✅ DecisionTree_DelOutlier_AmountLog1p_Timedrop
# ✅ DecisionTree_DelOutlier_Amount_Timedrop
# ✅ dt_ho_best
# ✅ dt_ho_best
# ✅ dt_ho_best_ejm
# ✅ DT_notScaled_balanced
# ✅ DT_notScaled_basic
# ✅ DT_notScaled_combined
# ✅ DT_notScaled_smote
# ✅ DT_notScaled_under
# ✅ DT_robustScaler_HO
# ✅ DT_robustScaler_HO_combined
# ✅ DT_robustScaler_HO_smote
# ✅ DT_robustScaler_HO_under
# ❌ JSON 파싱 오류: Ensemble_gb+rf+xgb=metaLR_20251201.txt
# ✅ gb_ho_best
# ✅ GB_HO_StandardScaled_sampled
# ✅ GB_HO_StandardScaled_sampled_v2
# ✅ GB_notScaled_basic
# ✅ GB_notScaled_combined
# ✅ GB_notScaled_smote
# ✅ GB_notScaled_under
# ✅ GB_robustScaler_HO
# ✅ GB_robustScaler_HO_combined
# ✅ GB_robustScaler_HO_smote
# ✅ GB_robustScaler_HO_under
# ✅ GradientBoosting_Amount_Timedrop
# ✅ GradientBoosting_DelOutlier_AmountLog1p_Timedrop
# ✅ GradientBoosting_DelOutlier_Amount_Timedrop
# ✅ hgb_ho_best
# ✅ hgb_SMOTE_ho_best
# ✅ lgb_ho_best
# ✅ LightGBM_DelOutlier_AmountLog1p_Timedrop
# ✅ LightGBM_DelOutlier_Amount_Timedrop
# ✅ LinearR_HO_StandardScaled
# ✅ LinearR_standardScaler_basic
# ✅ LinearR_standardScaler_combined
# ✅ LinearR_standardScaler_smote
# ✅ LinearR_standardScaler_under
# ✅ LiR_ho_best
# ✅ LogisticRegression_AmountLog1pScaled_Timedrop_Original
# ✅ LogisticRegression_AmountLog1pScaled_Timedrop_SMOTETomek
# ✅ LogisticRegression_AmountLog1pScaled_Timedrop_SMOTE
# ✅ LogisticRegression_AmountLog1pScaled_Timedrop_UnderSampling
# ✅ LogisticRegression_notscaled_Timedrop
# ✅ LogisticRegression_notscaled_Timedrop_combined
# ✅ LogisticRegression_notscaled_Timedrop_oversampled
# ✅ LogisticRegression_notscaled_Timedrop_undersampled
# ✅ LogisticR_HO_StandardScaled
# ✅ LogReg_Amount_Timedrop
# ✅ LogReg_DelOutlier_AmountLog1p_Timedrop
# ✅ LogReg_DelOutlier_Amount_Timedrop
# ✅ LoR_ho_best
# ✅ LoR_over_ho_best
# ✅ lr_cap
# ✅ lr_cap_a
# ✅ lr_cap_over
# ✅ lr_raw
# ✅ lr_raw_a
# ✅ lr_robustScaler_HO
# ✅ lr_robustScaler_HO_combined
# ✅ lr_robustScaler_HO_smote
# ✅ lr_robustScaler_HO_under
# ✅ LR_standardScaler_basic
# ✅ LR_standardScaler_smote
# ✅ MLP_Amount_Timedrop
# ✅ MLP_DelOutlier_AmountLog1p_Timedrop
# ✅ MLP_DelOutlier_Amount_Timedrop
# ✅ mlp_robustScaler_HO
# ✅ mlp_robustScaler_HO_combined
# ✅ mlp_robustScaler_HO_smote
# ✅ mlp_robustScaler_HO_under
# ✅ MLP_standardScaler_basic
# ✅ MLP_standardScaler_combined
# ✅ MLP_standardScaler_smote
# ✅ MLP_standardScaler_under
# ✅ ovesample_capped_catboost_ejm
# ✅ ovesample_capped_dt_ejm
# ✅ ovesample_capped_gb_ejm
# ✅ ovesample_capped_mlp_ejm
# ✅ ovesample_catboost_ejm
# ✅ ovesample_dt_ejm
# ✅ ovesample_gb_ejm
# ✅ ovesample_mlp_ejm
# ✅ RandomForest_00samples
# ✅ rawdata_catboost_20251126
# ✅ rawdata_dt_20251126
# ✅ rawdata_gb_20251126
# ✅ rawdata_lr_20251126
# ✅ rawdata_mlp_20251126
# ✅ rf_ho_best
# ❌ JSON 파싱 오류: robustScaler_Results.txt
# ❌ JSON 파싱 오류: stacking_ho-best_smote_20251201.txt
# ✅ STACK_gb_rf_xgb_metaLR
# ❌ JSON 파싱 오류: SVC_rbf_HO_sampled_20251201.txt
# ❌ JSON 파싱 오류: SVC_rbf_HO_sampled_SMOTE_20251201.txt
# ✅ SVM_scaled_balanced
# ✅ SVM_scaled_basic
# ✅ undsample_capped_catboost_ejm
# ✅ undsample_capped_dt_ejm
# ✅ undsample_capped_gb_ejm
# ✅ undsample_capped_mlp_ejm
# ✅ XGB_HO
# ✅ xgb_ho_best
# ❌ JSON 파싱 오류: xgb_ho_over_best2_20251128.txt
# ❌ JSON 파싱 오류: xgb_ho_over_best_20251128.txt
# ✅ xgb_ho_rsaled_best
# ✅ XGB_ho_rscaled
# ✅ XGB_ho_rscaled_combined
# ✅ XGB_ho_rscaled_smote
# ✅ XGB_ho_rscaled_under
# ✅ xgb_ho_ssaled_best
# ✅ xgb_ho_tr_over_best
# ✅ XGB_robustScaler_HO
# ✅ XGB_robustScaler_HO_combined
# ✅ LGBMClassifier_result
# ✅ LGBMClassifier_result
# ✅ LGBMClassifier_result
# ✅ LGBMClassifier_result
# ✅ LinearSVC_result
# ✅ LinearSVC_result
# ✅ LinearSVC_result
# ✅ LinearSVC_result
# ✅ RandomForestClassifier_result
# ✅ RandomForestClassifier_result
# ✅ RandomForestClassifier_result
# ✅ RandomForestClassifier_result
# ✅ RandomForestClassifier_result
# ✅ RandomForestClassifier_result
# ✅ RandomForestClassifier_result
# ✅ SGDClassifier_result
# ✅ SGDClassifier_result
# ✅ SGDClassifier_result
# ✅ SGDClassifier_result
# ✅ SGDClassifier_result
# ✅ SGDClassifier_result
# ✅ SGDClassifier_result
# ✅ SGDClassifier_result
# ✅ SGDClassifier_result
# ✅ stack1(cat+xgb+lgbm)_ho_best
# ✅ stack4(xgb+lsvc+lr)_ho_best
#
# ================================================================================
# ✅ 총 145개 모델 결과 로드 완료
# 📊 컬럼: ['model_name', 'file_name', 'AUC', '정확도', '정밀도', '재현율', 'F1', 'F2', '실행시간']
#
# ⚠️  오류 파일: 9개
# ================================================================================
#
#
# ⚠️  중복된 모델명 발견:
#                    model_name                                          file_name
#                    cb_ho_best                            cb_ho_best_20251130.txt
#                    cb_ho_best                            cb_ho_best_20251128.txt
# RandomForestClassifier_result RandomForestClassifier_result_20251130_155808.json
# RandomForestClassifier_result RandomForestClassifier_result_20251130_155351.json
#          SGDClassifier_result          SGDClassifier_result_20251130_150155.json
#          SGDClassifier_result          SGDClassifier_result_20251129_232126.json
#          SGDClassifier_result          SGDClassifier_result_20251130_150315.json
#          SGDClassifier_result          SGDClassifier_result_20251130_150213.json
#          SGDClassifier_result          SGDClassifier_result_20251129_232247.json
#          SGDClassifier_result          SGDClassifier_result_20251130_150345.json
#          SGDClassifier_result          SGDClassifier_result_20251130_150326.json
#          SGDClassifier_result          SGDClassifier_result_20251129_232227.json
#          SGDClassifier_result          SGDClassifier_result_20251130_150231.json
#                    dt_ho_best                            dt_ho_best_20251128.txt
#                    dt_ho_best                            dt_ho_best_20251130.txt
#         LGBMClassifier_result         LGBMClassifier_result_20251130_140754.json
#         LGBMClassifier_result         LGBMClassifier_result_20251130_140733.json
#         LGBMClassifier_result         LGBMClassifier_result_20251130_140921.json
#         LGBMClassifier_result         LGBMClassifier_result_20251130_140811.json
# RandomForestClassifier_result RandomForestClassifier_result_20251130_154419.json
# RandomForestClassifier_result RandomForestClassifier_result_20251130_154618.json
# RandomForestClassifier_result RandomForestClassifier_result_20251130_154804.json
# RandomForestClassifier_result RandomForestClassifier_result_20251130_155008.json
# RandomForestClassifier_result RandomForestClassifier_result_20251130_153804.json
#              LinearSVC_result              LinearSVC_result_20251130_014516.json
#              LinearSVC_result              LinearSVC_result_20251130_014522.json
#              LinearSVC_result              LinearSVC_result_20251130_014528.json
#              LinearSVC_result              LinearSVC_result_20251130_014454.json
#
# 📈 F1 점수 상위 10개 모델:
#                    model_name    AUC     F1  F2    정밀도    재현율
#      ovesample_capped_mlp_ejm 1.0000 0.9997 NaN 0.9994 1.0000
# ovesample_capped_catboost_ejm 1.0000 0.9995 NaN 0.9991 1.0000
#             ovesample_mlp_ejm 1.0000 0.9994 NaN 0.9991 0.9996
#        ovesample_catboost_ejm 1.0000 0.9992 NaN 0.9985 1.0000
#       ovesample_capped_dt_ejm 0.9982 0.9983 NaN 0.9975 0.9990
#              ovesample_dt_ejm 0.9982 0.9982 NaN 0.9974 0.9990
#       ovesample_capped_gb_ejm 0.9985 0.9787 NaN 0.9863 0.9713
#              ovesample_gb_ejm 0.9983 0.9764 NaN 0.9857 0.9674
#                   lr_cap_over 0.9921 0.9588 NaN 0.9816 0.9371
#      undsample_capped_mlp_ejm 0.9774 0.9375 NaN 0.9574 0.9184
