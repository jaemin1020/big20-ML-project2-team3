# %%
# 데이터 확인하기 2025.11.19
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler # 데이터 전처리용

# %%
# 원본 데이터 불러오기
train = pd.read_csv("../data/train.csv")
test = pd.read_csv("../data/test.csv")

# %%
remove_cols = pd.read_csv('../doc/remove_cols.xls', header=0).squeeze()
train.drop(columns=remove_cols, axis=1, inplace=True)
test.drop(columns=remove_cols, axis=1, inplace=True)

# %%
X_features = train.drop(columns=['ID', 'TARGET'], axis=1) # ID와 TARGET 모두 제거하고 X_train 만들기
y_labels = train['TARGET']
X_test = test.drop(columns=['ID'], axis=1) # test데이터 ID 제거
X_features.columns
# Out:
# Index(['var3', 'var15', 'imp_ent_var16_ult1', 'imp_op_var39_comer_ult1',
#        'imp_op_var39_comer_ult3', 'imp_op_var41_comer_ult1',
#        'imp_op_var41_comer_ult3', 'imp_op_var41_efect_ult1',
#        'imp_op_var41_efect_ult3', 'imp_op_var41_ult1',
#        ...
#        'saldo_medio_var8_ult3', 'saldo_medio_var12_hace2',
#        'saldo_medio_var12_hace3', 'saldo_medio_var12_ult1',
#        'saldo_medio_var12_ult3', 'saldo_medio_var13_corto_hace2',
#        'saldo_medio_var13_corto_hace3', 'saldo_medio_var13_corto_ult1',
#        'saldo_medio_var13_corto_ult3', 'var38'],
#       dtype='object', length=149)

# %%
# Data 전처리 2. var3 의 최소값 -99999 를 최빈값으로 변경하기
X_features['var3'] = X_features['var3'].replace(-999999, 2)

# %%
# 152개 컬럼의 데이터 전처리한 것 저장해 두기, 다음에 다시 테스트할때 대비
# X_features.to_csv('../data/x_train_149cols.csv')
# X_test.to_csv('../data/x_test_149cols.csv')

# %%
scaler        = StandardScaler()
X_scaled      = scaler.fit_transform(X_features)
X_test_scaled = scaler.transform(X_test)

# %%
# 레이블의 분포 확인
cust_cnt = y_labels.value_counts()
print(cust_cnt) # 1이 불만족 3008명, 만족이 73012

# 불만족고객의 비율
cust_rate = cust_cnt[1] / cust_cnt.sum()
print(f'불만족 고객 비율: {cust_rate:.2f}')
# Out:
# TARGET
# 0    73012
# 1     3008
# Name: count, dtype: int64
# 불만족 고객 비율: 0.04

# %%
# type(X_scaled)
# Out:
# numpy.ndarray

# %%
# 상관관계 시각화 시도
# 1. numpy array를 DataFrame으로 변환 (컬럼명 복원)
X_scaled_df = pd.DataFrame(X_scaled, columns=X_features.columns)

# 2. 상관관계 행렬 계산
correlation_matrix = X_scaled_df.corr()

# 3. 상관관계 히트맵 시각화
plt.figure(figsize=(20, 16))
sns.heatmap(correlation_matrix, 
            annot=False,  # 숫자 표시 (변수가 많으면 False)
            cmap='coolwarm',  # 색상 테마
            center=0,  # 0을 중심으로
            vmin=-1, vmax=1,  # 범위 -1 ~ 1
            square=True,  # 정사각형 셀
            linewidths=0.5,  # 셀 구분선
            cbar_kws={"shrink": 0.8})  # 컬러바 크기

plt.title('Correlation Matrix of Scaled Features', fontsize=16, pad=20)
plt.tight_layout()
plt.show()

# 4. 상관관계 통계 요약
print("=" * 60)
print("상관관계 통계 요약")
print("=" * 60)

# 대각선(자기 자신과의 상관관계) 제외
corr_values = correlation_matrix.values[np.triu_indices_from(correlation_matrix.values, k=1)]
print(f"평균 상관계수: {corr_values.mean():.4f}")
print(f"최대 상관계수: {corr_values.max():.4f}")
print(f"최소 상관계수: {corr_values.min():.4f}")
print(f"표준편차: {corr_values.std():.4f}")

# 5. 높은 상관관계 쌍 찾기 (절댓값 기준)
print("\n" + "=" * 60)
print("높은 상관관계 변수 쌍 (|correlation| > 0.7)")
print("=" * 60)

# 상위 삼각 행렬만 추출 (중복 제거)
upper_tri = correlation_matrix.where(
    np.triu(np.ones(correlation_matrix.shape), k=1).astype(bool)
)

# 높은 상관관계 찾기
high_corr = []
for column in upper_tri.columns:
    for index in upper_tri.index:
        corr_val = upper_tri.loc[index, column]
        if pd.notna(corr_val) and abs(corr_val) > 0.7:
            high_corr.append({
                'Variable 1': index,
                'Variable 2': column,
                'Correlation': corr_val
            })

high_corr_df = pd.DataFrame(high_corr).sort_values('Correlation', 
                                                     key=abs, 
                                                     ascending=False)
print(high_corr_df.to_string(index=False))
print(f"\n총 {len(high_corr_df)}개의 높은 상관관계 쌍 발견")

# 6. 특정 변수와의 상관관계 (예: 'var15'와의 상관관계)
if 'var15' in X_scaled_df.columns:
    print("\n" + "=" * 60)
    print("'var15'와 상관관계가 높은 변수들 (상위 10개)")
    print("=" * 60)
    var15_corr = correlation_matrix['var15'].abs().sort_values(ascending=False)
    print(var15_corr.head(11)[1:])  # 자기 자신 제외

# 7. 상관관계 분포 히스토그램
plt.figure(figsize=(10, 6))
plt.hist(corr_values, bins=50, edgecolor='black', alpha=0.7)
plt.xlabel('Correlation Coefficient', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Distribution of Correlation Coefficients', fontsize=14)
plt.axvline(x=0, color='red', linestyle='--', linewidth=2, label='Zero correlation')
plt.axvline(x=0.7, color='green', linestyle='--', linewidth=1, label='High positive (0.7)')
plt.axvline(x=-0.7, color='green', linestyle='--', linewidth=1, label='High negative (-0.7)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# ============================================================
# 상관관계 통계 요약
# ============================================================
# 평균 상관계수: 0.1249
# 최대 상관계수: 1.0000
# 최소 상관계수: -0.8659
# 표준편차: 0.2075
#
# ============================================================
# 높은 상관관계 변수 쌍 (|correlation| > 0.7)
# ============================================================
#                    Variable 1                    Variable 2  Correlation
#     delta_imp_aport_var13_1y3     delta_num_aport_var13_1y3     1.000000
#                   num_var26_0                     num_var26     1.000000
#                   ind_var25_0                     ind_var25     1.000000
#                   ind_var37_0                     ind_var37     1.000000
#                   ind_var26_0                     ind_var26     1.000000
#                   num_var37_0                     num_var37     1.000000
#                   num_var25_0                     num_var25     1.000000
#                      ind_var8                      num_var8     1.000000
#                    ind_var8_0                    num_var8_0     0.999793
#               ind_var13_corto               num_var13_corto     0.999670
#                     ind_var24                     num_var24     0.999461
#                   ind_var40_0                   num_var40_0     0.999420
#       imp_op_var41_efect_ult3       imp_op_var39_efect_ult3     0.999271
#       num_op_var41_efect_ult3       num_op_var39_efect_ult3     0.999244
#       num_op_var41_efect_ult1       num_op_var39_efect_ult1     0.998966
#                    ind_var1_0                    num_var1_0     0.998849
#       imp_op_var41_efect_ult1       imp_op_var39_efect_ult1     0.998378
#                    ind_var1_0                   ind_var40_0     0.998256
#            num_med_var45_ult3                num_var45_ult3     0.997806
#                    num_var1_0                   num_var40_0     0.997691
#                    ind_var1_0                   num_var40_0     0.997677
#                   ind_var24_0                   num_var24_0     0.997448
#                   ind_var40_0                    num_var1_0     0.997115
#                   saldo_var12                   saldo_var24     0.996932
#             ind_var13_corto_0             num_var13_corto_0     0.994177
#                      ind_var5                      num_var5     0.993709
#            num_op_var41_hace2            num_op_var39_hace2     0.992596
#                     ind_var12                     num_var12     0.992316
#             imp_op_var41_ult1             imp_op_var39_ult1     0.991103
#                   ind_var39_0                   ind_var41_0     0.989559
#            num_op_var41_hace3            num_op_var39_hace3     0.989116
#             num_op_var41_ult3             num_op_var39_ult3     0.988861
#             saldo_var13_corto  saldo_medio_var13_corto_ult1     0.988667
#  saldo_medio_var13_corto_ult1  saldo_medio_var13_corto_ult3     0.988373
#             num_op_var41_ult1             num_op_var39_ult1     0.986411
#                   saldo_var12        saldo_medio_var12_ult1     0.986397
#        saldo_medio_var12_ult1        saldo_medio_var12_ult3     0.985940
#                   ind_var13_0                     ind_var13     0.985841
#                   saldo_var26                   saldo_var25     0.985233
#                   saldo_var24        saldo_medio_var12_ult1     0.984636
#                      num_var4                     num_var35     0.983125
#             ind_var13_corto_0               ind_var13_corto     0.982100
#             ind_var13_corto_0               num_var13_corto     0.981776
#             saldo_var13_corto  saldo_medio_var13_corto_ult3     0.980455
#                     ind_var26                     ind_var25     0.979000
#                   ind_var26_0                     ind_var25     0.979000
#                     ind_var26                   ind_var25_0     0.979000
#                   ind_var26_0                   ind_var25_0     0.979000
#                 ind_var25_cte                 ind_var26_cte     0.978691
#                   saldo_var12                   saldo_var42     0.978415
#                   num_var13_0                     num_var13     0.977917
#             num_var13_corto_0               num_var13_corto     0.976785
#               ind_var13_corto             num_var13_corto_0     0.976475
#                   saldo_var24                   saldo_var42     0.975267
#                     num_var26                   num_var25_0     0.974992
#                   num_var26_0                     num_var25     0.974992
#                   num_var26_0                   num_var25_0     0.974992
#                     num_var26                     num_var25     0.974992
#       num_op_var39_comer_ult1       num_op_var41_comer_ult1     0.973520
#                   saldo_var12        saldo_medio_var12_ult3     0.973450
#             ind_var10cte_ult1             ind_var9_cte_ult1     0.972857
#                   saldo_var24        saldo_medio_var12_ult3     0.972077
#                     ind_var13                     num_var13     0.968384
#                ind_var10_ult1                 ind_var9_ult1     0.967573
#                   saldo_var42        saldo_medio_var12_ult1     0.965058
#       imp_op_var39_comer_ult1       imp_op_var41_comer_ult1     0.961781
#             ind_var13_corto_0    num_meses_var13_corto_ult3     0.960857
#       imp_op_var39_comer_ult3       imp_op_var41_comer_ult3     0.959840
#       num_op_var39_comer_ult3       num_op_var41_comer_ult3     0.957859
#                   ind_var13_0                   num_var13_0     0.957759
#               ind_var13_corto    num_meses_var13_corto_ult3     0.956652
#               num_var13_corto    num_meses_var13_corto_ult3     0.956246
#             num_var13_corto_0    num_meses_var13_corto_ult3     0.955846
#                   ind_var13_0                     num_var13     0.954673
#                   saldo_var42        saldo_medio_var12_ult3     0.952447
#                     ind_var12          num_meses_var12_ult3     0.952131
#                   num_var39_0                   num_var41_0     0.950177
#                num_var22_ult3            num_med_var22_ult3     0.948403
#         saldo_medio_var8_ult1         saldo_medio_var8_ult3     0.946984
#                 ind_var37_cte                     ind_var37     0.946499
#                 ind_var37_cte                   ind_var37_0     0.946499
#                     ind_var13                   num_var13_0     0.945745
#                     num_var12          num_meses_var12_ult3     0.944888
#                 ind_var25_cte                   ind_var25_0     0.944415
#                 ind_var25_cte                     ind_var25     0.944415
#                   ind_var26_0                 ind_var26_cte     0.944117
#                 ind_var26_cte                     ind_var26     0.944117
#                   ind_var24_0                     ind_var24     0.943379
#                   ind_var24_0                     num_var24     0.942870
#                   num_var24_0                     num_var24     0.941980
#                     ind_var24                   num_var24_0     0.941475
#             num_op_var41_ult1       num_op_var41_comer_ult1     0.939905
#             ind_var9_cte_ult1                 ind_var9_ult1     0.936083
#             num_op_var39_ult1             num_op_var39_ult3     0.935459
#             num_op_var41_ult1             num_op_var41_ult3     0.934250
#             num_op_var39_ult1       num_op_var39_comer_ult1     0.931719
#                    ind_var8_0                      ind_var8     0.931233
#                    ind_var8_0                      num_var8     0.931233
#                    num_var8_0                      num_var8     0.931098
#                      ind_var8                    num_var8_0     0.931098
#                ind_var10_ult1             ind_var10cte_ult1     0.930998
#             num_op_var39_ult1       num_op_var41_comer_ult1     0.927009
#            num_var37_med_ult2                     num_var37     0.926191
#            num_var37_med_ult2                   num_var37_0     0.926191
#                    saldo_var8         saldo_medio_var8_ult1     0.925523
#                 ind_var25_cte                   ind_var26_0     0.924468
#                 ind_var25_cte                     ind_var26     0.924468
#                 ind_var26_cte                   ind_var25_0     0.924290
#                 ind_var26_cte                     ind_var25     0.924290
#             num_op_var41_ult1             num_op_var39_ult3     0.923679
#                    ind_var5_0                    num_var5_0     0.922780
#             num_op_var41_ult3             num_op_var39_ult1     0.922523
#       saldo_medio_var12_hace2        saldo_medio_var12_ult3     0.921340
# saldo_medio_var13_corto_hace2  saldo_medio_var13_corto_ult3     0.920977
#             num_op_var41_ult3       num_op_var41_comer_ult3     0.920593
#       num_op_var41_comer_ult1       num_op_var41_comer_ult3     0.919436
# saldo_medio_var13_corto_hace2  saldo_medio_var13_corto_ult1     0.919280
#       num_op_var39_comer_ult1       num_op_var39_comer_ult3     0.917705
#                      ind_var8           num_meses_var8_ult3     0.917529
#                      num_var8           num_meses_var8_ult3     0.917529
#       saldo_medio_var12_hace2        saldo_medio_var12_ult1     0.916872
#             num_op_var41_ult1       num_op_var39_comer_ult1     0.915419
#             num_op_var39_ult3       num_op_var41_comer_ult3     0.910808
#               num_var45_hace2                num_var45_ult3     0.909958
#             ind_var13_largo_0             num_var13_largo_0     0.909868
#                     ind_var12                     ind_var24     0.909269
#                      ind_var5           num_meses_var5_ult3     0.908842
#                     ind_var12                     num_var24     0.908779
#            num_med_var45_ult3               num_var45_hace2     0.908124
#                   num_var12_0                   num_var42_0     0.908086
#                ind_var10_ult1             ind_var9_cte_ult1     0.905728
#                   ind_var41_0                   num_var41_0     0.904877
#             ind_var10cte_ult1                 ind_var9_ult1     0.904102
#                     num_var12                     num_var24     0.903997
#                     ind_var24                     num_var12     0.903526
#                      num_var5           num_meses_var5_ult3     0.903272
#       num_op_var41_efect_ult1       num_op_var41_efect_ult3     0.903254
#       num_op_var39_efect_ult1       num_op_var39_efect_ult3     0.903253
#       num_op_var41_efect_ult1       num_op_var39_efect_ult3     0.902839
#       num_op_var41_efect_ult3       num_op_var39_efect_ult1     0.902156
#                   ind_var13_0             ind_var13_corto_0     0.902084
#               ind_var13_corto                     ind_var13     0.898661
#             num_op_var39_ult3       num_op_var39_comer_ult3     0.898395
#                     ind_var13               num_var13_corto     0.898364
#                     num_var30                     num_var42     0.898119
#                   ind_var13_0             num_var13_corto_0     0.896832
#       num_op_var39_comer_ult1       num_op_var41_comer_ult3     0.896654
#                   ind_var39_0                   num_var41_0     0.895501
#             saldo_var13_corto saldo_medio_var13_corto_hace2     0.894967
#                   ind_var26_0                     num_var26     0.894686
#                   ind_var26_0                   num_var26_0     0.894686
#                     ind_var26                   num_var26_0     0.894686
#                     ind_var26                     num_var26     0.894686
#                     ind_var30                     num_var42     0.894182
#                     ind_var25                     num_var25     0.894157
#                   ind_var25_0                     num_var25     0.894157
#                   ind_var25_0                   num_var25_0     0.894157
#                     ind_var25                   num_var25_0     0.894157
#                   ind_var37_0                ind_var10_ult1     0.890758
#                     ind_var37                ind_var10_ult1     0.890758
#                   saldo_var24       saldo_medio_var12_hace2     0.887247
#                   saldo_var12       saldo_medio_var12_hace2     0.886511
#       imp_op_var39_comer_ult1       imp_op_var39_comer_ult3     0.886476
#                   ind_var13_0               ind_var13_corto     0.885937
#       imp_op_var41_comer_ult1       imp_op_var41_comer_ult3     0.885836
#                   ind_var13_0               num_var13_corto     0.885645
#             ind_var13_corto_0                     ind_var13     0.885503
#       imp_op_var41_efect_ult1             imp_op_var41_ult1     0.885353
#             imp_op_var41_ult1       imp_op_var39_efect_ult1     0.883892
#                   ind_var12_0                   num_var12_0     0.881832
#             num_op_var41_ult3       num_op_var39_comer_ult3     0.880639
#       num_op_var39_comer_ult3       num_op_var41_comer_ult1     0.880436
#                     ind_var13             num_var13_corto_0     0.880395
#                   ind_var39_0                   num_var39_0     0.880173
#                     ind_var24          num_meses_var12_ult3     0.879919
#                     num_var24          num_meses_var12_ult3     0.879473
#             num_op_var41_ult3       num_op_var41_comer_ult1     0.878602
#       imp_op_var39_efect_ult1             imp_op_var39_ult1     0.878124
#       imp_op_var41_efect_ult1             imp_op_var39_ult1     0.877598
#                 ind_var37_cte             ind_var10cte_ult1     0.876170
#                     ind_var30                     num_var30     0.875812
#                     ind_var26                     num_var25     0.875380
#                   ind_var26_0                   num_var25_0     0.875380
#                   ind_var26_0                     num_var25     0.875380
#                     ind_var26                   num_var25_0     0.875380
#            num_med_var45_ult3                num_var45_ult1     0.874059
#                num_var45_ult1                num_var45_ult3     0.873370
#                   ind_var25_0                     num_var26     0.872553
#                     ind_var25                     num_var26     0.872553
#                     ind_var25                   num_var26_0     0.872553
#                   ind_var25_0                   num_var26_0     0.872553
#             num_op_var39_ult3       num_op_var39_comer_ult1     0.871874
#                   ind_var41_0                   num_var39_0     0.871449
#                     ind_var30           num_meses_var5_ult3     0.869045
#             num_op_var39_ult3       num_op_var41_comer_ult1     0.868803
#                    ind_var8_0           num_meses_var8_ult3     0.868478
#                    num_var8_0           num_meses_var8_ult3     0.868379
#                   saldo_var42       saldo_medio_var12_hace2     0.867240
#            num_op_var41_hace2             num_op_var41_ult3     0.867120
#            num_op_var39_hace2             num_op_var39_ult3     0.866894
#                   ind_var13_0    num_meses_var13_corto_ult3     0.866774
#                    ind_var5_0                    ind_var8_0    -0.865874
#                    ind_var5_0                    num_var8_0    -0.865701
#                   ind_var37_0                 ind_var9_ult1     0.861873
#                     ind_var37                 ind_var9_ult1     0.861873
#                     ind_var13    num_meses_var13_corto_ult3     0.861114
#             num_op_var41_ult3            num_op_var39_hace2     0.860775
#            num_op_var41_hace2             num_op_var39_ult3     0.857829
#                     ind_var12                   ind_var24_0     0.857257
#       imp_op_var39_comer_ult1       imp_op_var41_comer_ult3     0.856878
#             num_op_var41_ult3       num_op_var39_comer_ult1     0.856522
#             num_op_var41_ult1       num_op_var41_comer_ult3     0.855584
#                     ind_var12                   num_var24_0     0.855530
#                    saldo_var8         saldo_medio_var8_ult3     0.853718
#             saldo_var13_corto                   saldo_var13     0.853542
#                 ind_var37_cte             ind_var9_cte_ult1     0.852388
#                   ind_var24_0                     num_var12     0.851844
#                     num_var12                   num_var24_0     0.850988
#                 ind_var37_cte                ind_var10_ult1     0.849448
#       imp_op_var39_comer_ult3       imp_op_var41_comer_ult1     0.848845
#                      ind_var5                     ind_var30     0.848338
#             num_op_var39_ult1       num_op_var41_comer_ult3     0.845178
#                 ind_var26_cte                     num_var26     0.844688
#                 ind_var26_cte                   num_var26_0     0.844688
#               num_var13_corto                     num_var13     0.844681
#                   saldo_var13  saldo_medio_var13_corto_ult1     0.844506
#                 ind_var25_cte                     num_var25     0.844455
#                 ind_var25_cte                   num_var25_0     0.844455
#               ind_var13_corto                     num_var13     0.844415
#                     ind_var30                      num_var5     0.843001
#                   num_var30_0                   num_var42_0     0.840657
#                   num_var13_0             num_var13_corto_0     0.839683
#                      num_var5                     num_var42     0.839574
#                    saldo_var5         saldo_medio_var5_ult1     0.838142
#             num_op_var39_ult1       num_op_var39_comer_ult3     0.837851
#                   saldo_var13  saldo_medio_var13_corto_ult3     0.836556
#             ind_var13_corto_0                   num_var13_0     0.835150
#         saldo_medio_var5_ult1         saldo_medio_var5_ult3     0.834784
#                   ind_var24_0          num_meses_var12_ult3     0.833074
#             ind_var13_corto_0                     num_var13     0.833047
#                      ind_var5                     num_var42     0.832502
#                   num_var24_0          num_meses_var12_ult3     0.831551
#                   ind_var37_0             ind_var10cte_ult1     0.829294
#                     ind_var37             ind_var10cte_ult1     0.829294
#             num_var13_corto_0                     num_var13     0.828586
#                 ind_var26_cte                     num_var25     0.826461
#                 ind_var26_cte                   num_var25_0     0.826461
#       imp_op_var41_comer_ult3       num_op_var41_comer_ult3     0.824280
#                 ind_var25_cte                     num_var26     0.823940
#                 ind_var25_cte                   num_var26_0     0.823940
#                 ind_var37_cte                 ind_var9_ult1     0.822682
#       imp_op_var39_comer_ult3       num_op_var39_comer_ult3     0.822368
#             num_op_var41_ult1       num_op_var39_comer_ult3     0.818906
#                   num_var13_0               num_var13_corto     0.817264
#               ind_var13_corto                   num_var13_0     0.817020
#                     num_var42           num_meses_var5_ult3     0.813847
#                     num_var13    num_meses_var13_corto_ult3     0.811353
#                   ind_var12_0                     ind_var12     0.811006
#       imp_op_var39_efect_ult1       imp_op_var39_efect_ult3     0.810847
#       imp_op_var41_efect_ult1       imp_op_var39_efect_ult3     0.810787
#       imp_op_var41_efect_ult1       imp_op_var41_efect_ult3     0.810084
#                   ind_var39_0      num_meses_var39_vig_ult3     0.808463
#       imp_op_var41_efect_ult3       imp_op_var39_efect_ult1     0.808220
#                    ind_var5_0                      ind_var8    -0.807106
#                    ind_var5_0                      num_var8    -0.807106
#                     ind_var37             ind_var9_cte_ult1     0.806784
#                   ind_var37_0             ind_var9_cte_ult1     0.806784
#                   ind_var12_0                     num_var12     0.804774
#            num_op_var41_hace2       num_op_var41_comer_ult3     0.804746
#                   ind_var41_0      num_meses_var39_vig_ult3     0.803424
#                   num_var13_0    num_meses_var13_corto_ult3     0.802910
#                      ind_var8                 ind_var26_cte     0.800346
#                 ind_var26_cte                      num_var8     0.800346
#            num_op_var39_hace2       num_op_var41_comer_ult3     0.799489
#                    ind_var8_0                    num_var5_0    -0.798428
#                    num_var5_0                    num_var8_0    -0.798268
#       imp_op_var41_comer_ult1       num_op_var41_comer_ult1     0.793713
#       imp_op_var41_comer_ult3       num_op_var39_comer_ult3     0.793661
#                   saldo_var30                   saldo_var42     0.792772
#                   num_var12_0                   num_var30_0     0.791023
#       imp_op_var39_comer_ult1       num_op_var39_comer_ult1     0.790710
#                   ind_var12_0                   num_var42_0     0.789381
#       imp_op_var39_comer_ult3       num_op_var41_comer_ult3     0.788542
#                      ind_var8                 ind_var25_cte     0.784574
#                 ind_var25_cte                      num_var8     0.784574
#               num_var22_hace2                num_var22_ult3     0.783333
#            num_op_var39_hace2       num_op_var39_comer_ult3     0.782705
#                   ind_var12_0                   ind_var24_0     0.781682
#                   ind_var12_0                   num_var24_0     0.779688
#                   ind_var12_0          num_meses_var12_ult3     0.777429
#       imp_op_var41_comer_ult1       num_op_var39_comer_ult1     0.775888
#                   saldo_var12                   saldo_var30     0.775163
#                   saldo_var24                   saldo_var30     0.772290
#            num_op_var41_hace2       num_op_var39_comer_ult3     0.769391
#                   ind_var40_0                         var21     0.769026
#                   num_var40_0                         var21     0.768250
#           imp_var43_emit_ult1          imp_trans_var37_ult1     0.768089
#                    ind_var1_0                         var21     0.767685
#                    num_var1_0                         var21     0.766525
#                   saldo_var13 saldo_medio_var13_corto_hace2     0.766367
#                   ind_var14_0                   num_var14_0     0.764624
#                   saldo_var30        saldo_medio_var12_ult1     0.764615
#       imp_op_var39_comer_ult1       num_op_var41_comer_ult1     0.763590
#                     num_var30           num_meses_var5_ult3     0.756298
#                    ind_var8_0                 ind_var26_cte     0.754041
#                 ind_var26_cte                    num_var8_0     0.754022
#                   saldo_var30        saldo_medio_var12_ult3     0.753437
#                   ind_var26_0                      num_var8     0.753209
#                     ind_var26                      num_var8     0.753209
#                      ind_var8                   ind_var26_0     0.753209
#                      ind_var8                     ind_var26     0.753209
#       imp_op_var39_comer_ult3       num_op_var39_comer_ult1     0.750993
#                    ind_var5_0           num_meses_var8_ult3    -0.750552
#                   num_var41_0      num_meses_var39_vig_ult3     0.749091
#       imp_op_var41_comer_ult3       num_op_var41_comer_ult1     0.748817
#       imp_op_var41_comer_ult1             num_op_var41_ult1     0.748070
#               num_var22_hace2            num_med_var22_ult3     0.745606
#       imp_op_var41_comer_ult3             num_op_var41_ult3     0.744793
#                      num_var5                     num_var30     0.744330
#                    num_var5_0                      num_var8    -0.744140
#                      ind_var8                    num_var5_0    -0.744140
#                     num_var13                   saldo_var13     0.740945
#        saldo_medio_var8_hace2         saldo_medio_var8_ult3     0.740936
#         imp_aport_var13_hace3         num_aport_var13_hace3     0.740895
#       imp_op_var41_comer_ult1             num_op_var39_ult1     0.739759
#       imp_op_var41_comer_ult3             num_op_var39_ult3     0.739144
#                    ind_var8_0                 ind_var25_cte     0.738649
#                 ind_var25_cte                    num_var8_0     0.738648
#       imp_op_var39_comer_ult1             num_op_var39_ult1     0.738363
#                   ind_var25_0                      num_var8     0.738017
#                     ind_var25                      num_var8     0.738017
#                      ind_var8                     ind_var25     0.738017
#                      ind_var8                   ind_var25_0     0.738017
#                      ind_var5                     num_var30     0.737867
#                   ind_var12_0                     ind_var24     0.737423
#                   ind_var12_0                     num_var24     0.737025
#               num_var13_corto             saldo_var13_corto     0.736146
#               ind_var13_corto             saldo_var13_corto     0.735971
#       imp_op_var41_comer_ult1       num_op_var41_comer_ult3     0.735967
#       imp_op_var41_comer_ult3       num_op_var39_comer_ult1     0.733861
#                      num_var4                     num_var30     0.733809
#                   num_var39_0      num_meses_var39_vig_ult3     0.732653
#       imp_op_var39_comer_ult3             num_op_var39_ult3     0.731686
#                     num_var30                     num_var35     0.731010
#                     ind_var13                   saldo_var13     0.729607
#       imp_op_var39_comer_ult1       num_op_var39_comer_ult3     0.728453
#               num_var13_corto  saldo_medio_var13_corto_ult1     0.728161
#                   num_var13_0                   num_var30_0     0.728016
#               ind_var13_corto  saldo_medio_var13_corto_ult1     0.727959
#                   num_var12_0                     num_var12     0.726604
#                   num_var13_0                   saldo_var13     0.726430
#                   ind_var12_0                   num_var30_0     0.724415
#             imp_op_var41_ult1       imp_op_var39_efect_ult3     0.724126
#       imp_op_var41_efect_ult3             imp_op_var41_ult1     0.723314
#               num_var45_hace3                num_var45_ult3     0.722962
#             ind_var13_corto_0             saldo_var13_corto     0.722798
#                     ind_var12                   num_var12_0     0.721529
#               num_var13_corto  saldo_medio_var13_corto_ult3     0.721055
#               ind_var13_corto  saldo_medio_var13_corto_ult3     0.720842
#             num_var13_corto_0             saldo_var13_corto     0.720779
#       imp_op_var39_comer_ult1             num_op_var41_ult1     0.720446
#       imp_op_var39_efect_ult3             imp_op_var39_ult1     0.719367
#                   ind_var13_0                   saldo_var13     0.719277
#        saldo_medio_var5_hace2         saldo_medio_var5_ult3     0.719011
#             ind_var13_corto_0  saldo_medio_var13_corto_ult1     0.718452
#            num_med_var45_ult3               num_var45_hace3     0.717549
#       imp_op_var41_efect_ult3             imp_op_var39_ult1     0.717237
#             num_var13_corto_0  saldo_medio_var13_corto_ult1     0.716710
#       imp_op_var39_comer_ult3       num_op_var41_comer_ult1     0.715507
#                   ind_var13_0                   num_var30_0     0.715471
#               num_var45_hace2                num_var45_ult1     0.714336
#    num_meses_var13_corto_ult3  saldo_medio_var13_corto_ult1     0.712841
#             ind_var13_corto_0  saldo_medio_var13_corto_ult3     0.712260
#       imp_op_var39_comer_ult3             num_op_var41_ult3     0.711012
#       imp_op_var39_comer_ult1       num_op_var41_comer_ult3     0.710507
#             num_var13_corto_0  saldo_medio_var13_corto_ult3     0.709751
#       imp_op_var41_comer_ult1       num_op_var39_comer_ult3     0.708234
#                     num_var13                   num_var30_0     0.707691
#                   ind_var26_0                    num_var8_0     0.707408
#                     ind_var26                    num_var8_0     0.707408
#                    ind_var8_0                   ind_var26_0     0.707374
#                    ind_var8_0                     ind_var26     0.707374
#                     ind_var37                     num_var37     0.707211
#                   ind_var37_0                     num_var37     0.707211
#                     ind_var37                   num_var37_0     0.707211
#                   ind_var37_0                   num_var37_0     0.707211
#                      num_var4                     num_var42     0.706539
#                   num_var12_0                   num_var14_0     0.703964
#    num_meses_var13_corto_ult3 saldo_medio_var13_corto_hace2     0.703806
#             saldo_var13_corto    num_meses_var13_corto_ult3     0.702971
#               num_var22_hace3                num_var22_ult3     0.702191
#             num_op_var41_ult3       num_op_var41_efect_ult3     0.700853
#             num_op_var41_ult3       num_op_var39_efect_ult3     0.700409
#                   num_var12_0                   num_var24_0     0.700306
#
# 총 394개의 높은 상관관계 쌍 발견
#
# ============================================================
# 'var15'와 상관관계가 높은 변수들 (상위 10개)
# ============================================================
# saldo_var30           0.325300
# num_var22_ult3        0.320926
# num_var30_0           0.314529
# ind_var13_0           0.300081
# ind_var13             0.298543
# num_var13             0.296705
# num_var13_0           0.295473
# num_var22_hace3       0.285993
# num_med_var22_ult3    0.266929
# saldo_var13           0.264309
# Name: var15, dtype: float64

# %%
# seaborn이 자동으로 클러스터링 처리
plt.figure(figsize=(20, 16))

g = sns.clustermap(correlation_matrix,
                   cmap='coolwarm',
                   center=0,
                   vmin=-1, vmax=1,
                   method='average',  # 클러스터링 방법
                   metric='correlation',  # 거리 측정 방법
                   figsize=(20, 16),
                   linewidths=0.5,
                   cbar_kws={"shrink": 0.8})

g.fig.suptitle('Clustered Correlation Matrix', fontsize=16, y=0.99)
plt.tight_layout()
plt.show()
# Out:
# c:\ProgramData\anaconda3\envs\ml_dev\Lib\site-packages\seaborn\matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# c:\ProgramData\anaconda3\envs\ml_dev\Lib\site-packages\seaborn\matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
# 상위 20개 변수만 선택
n_top = 20
top_vars = X_scaled_df.columns[:n_top]
top_corr = correlation_matrix.loc[top_vars, top_vars]

plt.figure(figsize=(12, 10))
sns.heatmap(top_corr, 
            annot=True,  # 숫자 표시
            fmt='.2f',  # 소수점 2자리
            cmap='coolwarm',
            center=0,
            vmin=-1, vmax=1,
            square=True,
            linewidths=0.5)

plt.title(f'Correlation Matrix (Top {n_top} Variables)', fontsize=14, pad=20)
plt.tight_layout()
plt.show()

# %%
import networkx as nx

# 높은 상관관계만 네트워크로 표현
threshold = 0.7
G = nx.Graph()

for i in range(len(correlation_matrix.columns)):
    for j in range(i+1, len(correlation_matrix.columns)):
        if abs(correlation_matrix.iloc[i, j]) > threshold:
            G.add_edge(
                correlation_matrix.columns[i],
                correlation_matrix.columns[j],
                weight=correlation_matrix.iloc[i, j]
            )

if len(G.edges()) > 0:
    plt.figure(figsize=(15, 15))
    pos = nx.spring_layout(G, k=2, iterations=50)
    
    # 엣지 색상 (양/음의 상관관계)
    edges = G.edges()
    weights = [G[u][v]['weight'] for u, v in edges]
    colors = ['red' if w < 0 else 'blue' for w in weights]
    
    nx.draw(G, pos,
            with_labels=True,
            node_color='lightblue',
            node_size=3000,
            font_size=10,
            font_weight='bold',
            edge_color=colors,
            width=2,
            alpha=0.7)
    
    plt.title(f'High Correlation Network (|r| > {threshold})', fontsize=16)
    plt.tight_layout()
    plt.show()
else:
    print(f"상관관계가 {threshold} 이상인 변수 쌍이 없습니다.")
# Out:
# C:\Users\TJ\AppData\Local\Temp\ipykernel_15336\2240095329.py:36: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
