# %%
import pandas as pd
import matplotlib.pyplot as plt

# 예시: Santander 데이터셋 로드
df = pd.read_csv("../data/train.csv")

# var15 분포 확인
print(df['var15'].value_counts())
# print(df['var15'].describe())

# 100세 이상 값 개수
print("100세 이상:", (df['var15'] > 100).sum())


# # 히스토그램
# plt.hist(df['var15'], bins=50, edgecolor='black')
# plt.axvline(100, color='red', linestyle='--', label='100세 기준선')
# plt.legend()
# plt.title("var15 (추정 나이) 분포")
# plt.xlabel("나이")
# plt.ylabel("빈도")
# plt.show()

# # 박스플롯
# plt.boxplot(df['var15'])
# plt.title("var15 Boxplot")
# plt.show()
# Out:
# count    76020.000000
# mean        33.212865
# std         12.956486
# min          5.000000
# 25%         23.000000
# 50%         28.000000
# 75%         40.000000
# max        105.000000
# Name: var15, dtype: float64
# var15
# 23     20170
# 24      6232
# 25      4217
# 26      3270
# 27      2861
#        ...
# 97         3
# 104        2
# 98         1
# 105        1
# 101        1
# Name: count, Length: 100, dtype: int64
# 100세 이상: 8
