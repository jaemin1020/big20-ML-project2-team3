# %%
# 데이터 확인(EDA) 2025.11.19
# 데이터 로드
import pandas as pd
import numpy as np

df = pd.read_csv('../data/train.csv')

# 데이터프레임 기본 확인
# print(df.head())
print(df.shape)
print(df.describe())
# Out:
# (76020, 371)
#                   ID           var3         var15  imp_ent_var16_ult1  \
# count   76020.000000   76020.000000  76020.000000        76020.000000
# mean    75964.050723   -1523.199277     33.212865           86.208265
# std     43781.947379   39033.462364     12.956486         1614.757313
# min         1.000000 -999999.000000      5.000000            0.000000
# 25%     38104.750000       2.000000     23.000000            0.000000
# 50%     76043.000000       2.000000     28.000000            0.000000
# 75%    113748.750000       2.000000     40.000000            0.000000
# max    151838.000000     238.000000    105.000000       210000.000000
#
#        imp_op_var39_comer_ult1  imp_op_var39_comer_ult3  \
# count             76020.000000             76020.000000
# mean                 72.363067               119.529632
# std                 339.315831               546.266294
# min                   0.000000                 0.000000
# ...

# %%
df['num_op_var40_efect_ult1'].describe()
# Out:
# count    76020.000000
# mean         0.002486
# std          0.147172
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         24.000000
# Name: num_op_var40_efect_ult1, dtype: float64

# %%
df['TARGET'].value_counts()
# Out:
# TARGET
# 0    73012
# 1     3008
# Name: count, dtype: int64

# %%
# import pandas as pd

# # describe 결과 얻기
# desc = df.describe()

# # 엑셀 파일로 저장
# desc.to_excel("df_describe.xlsx")

# %%
# # IQR, 하한값, 상한값, 이상치 개수 계산
# # DataFrame 으로 정리하고, to_excel() => 엑셀 파일로 내보내기
# import pandas as pd

# df = pd.read_csv("../data/train.csv")

# summary = {}
# for col in df.select_dtypes(include='number').columns:
#     Q1 = df[col].quantile(0.25)
#     Q3 = df[col].quantile(0.75)
#     IQR = Q3 - Q1
#     lower = Q1 - 1.5 * IQR
#     upper = Q3 + 1.5 * IQR
#     outliers = ((train[col] < lower) | (train[col] > upper)).sum()
#     summary[col] = {
#         "IQR": IQR,
#         "Lower Bound": lower,
#         "Upper Bound": upper,
#         "Outlier Count": outliers
#     }

# summary_df = pd.DataFrame(summary).T

# %%
# 엑셀로 저장
# summary_df.to_excel("train_outlier_summary.xlsx")
