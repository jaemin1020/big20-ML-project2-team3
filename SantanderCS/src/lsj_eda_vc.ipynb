# %%
# 데이터 확인하기 2025.11.19 value count 하기
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
from matplotlib import rc

plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
# 원본 데이터 불러오기
df = pd.read_csv("../data/train.csv")

# %%
myCols = ['imp_amort_var18_ult1','imp_amort_var34_hace3','imp_amort_var34_ult1','imp_aport_var13_hace3','imp_aport_var13_ult1','imp_aport_var17_hace3','imp_aport_var17_ult1','imp_aport_var33_hace3','imp_aport_var33_ult1','imp_var7_emit_ult1','imp_var7_recib_ult1','imp_compra_var44_hace3','imp_compra_var44_ult1','imp_reemb_var13_hace3','imp_reemb_var13_ult1','imp_reemb_var17_hace3','imp_reemb_var17_ult1','imp_reemb_var33_hace3','imp_reemb_var33_ult1','imp_var43_emit_ult1','imp_trans_var37_ult1','imp_trasp_var17_in_hace3','imp_trasp_var17_in_ult1','imp_trasp_var17_out_hace3','imp_trasp_var17_out_ult1','imp_trasp_var33_in_hace3','imp_trasp_var33_in_ult1','imp_trasp_var33_out_hace3','imp_trasp_var33_out_ult1','imp_venta_var44_hace3','imp_venta_var44_ult1','ind_var7_emit_ult1','ind_var7_recib_ult1','ind_var10_ult1','ind_var10cte_ult1','ind_var9_cte_ult1','ind_var9_ult1','ind_var43_emit_ult1','ind_var43_recib_ult1','var21','num_var2_0_ult1','num_var2_ult1','num_aport_var13_hace3','num_aport_var13_ult1','num_aport_var17_hace3','num_aport_var17_ult1','num_aport_var33_hace3','num_aport_var33_ult1','num_var7_emit_ult1','num_var7_recib_ult1','num_compra_var44_hace3','num_compra_var44_ult1','num_ent_var16_ult1','num_var22_hace2','num_var22_hace3','num_var22_ult1','num_var22_ult3','num_med_var22_ult3','num_med_var45_ult3','num_meses_var5_ult3','num_meses_var8_ult3','num_meses_var12_ult3','num_meses_var13_corto_ult3','num_meses_var13_largo_ult3','num_meses_var13_medio_ult3','num_meses_var17_ult3','num_meses_var29_ult3','num_meses_var33_ult3','num_meses_var39_vig_ult3','num_meses_var44_ult3','num_op_var39_comer_ult1','num_op_var39_comer_ult3','num_op_var40_comer_ult1','num_op_var40_comer_ult3']

allCols = df.columns[1:-1].to_list()
allCols
# Out:
# ['var3',
#  'var15',
#  'imp_ent_var16_ult1',
#  'imp_op_var39_comer_ult1',
#  'imp_op_var39_comer_ult3',
#  'imp_op_var40_comer_ult1',
#  'imp_op_var40_comer_ult3',
#  'imp_op_var40_efect_ult1',
#  'imp_op_var40_efect_ult3',
#  'imp_op_var40_ult1',
#  'imp_op_var41_comer_ult1',
#  'imp_op_var41_comer_ult3',
#  'imp_op_var41_efect_ult1',
#  'imp_op_var41_efect_ult3',
#  'imp_op_var41_ult1',
#  'imp_op_var39_efect_ult1',
#  'imp_op_var39_efect_ult3',
#  'imp_op_var39_ult1',
#  'imp_sal_var16_ult1',
#  'ind_var1_0',
#  'ind_var1',
#  'ind_var2_0',
#  'ind_var2',
#  'ind_var5_0',
#  'ind_var5',
#  'ind_var6_0',
#  'ind_var6',
#  'ind_var8_0',
#  'ind_var8',
#  'ind_var12_0',
#  'ind_var12',
#  'ind_var13_0',
#  'ind_var13_corto_0',
#  'ind_var13_corto',
#  'ind_var13_largo_0',
#  'ind_var13_largo',
#  'ind_var13_medio_0',
#  'ind_var13_medio',
#  'ind_var13',
#  'ind_var14_0',
#  'ind_var14',
#  'ind_var17_0',
#  'ind_var17',
#  'ind_var18_0',
#  'ind_var18',
#  'ind_var19',
#  'ind_var20_0',
#  'ind_var20',
#  'ind_var24_0',
#  'ind_var24',
#  'ind_var25_cte',
#  'ind_var26_0',
#  'ind_var26_cte',
#  'ind_var26',
#  'ind_var25_0',
#  'ind_var25',
#  'ind_var27_0',
#  'ind_var28_0',
#  'ind_var28',
#  'ind_var27',
#  'ind_var29_0',
#  'ind_var29',
#  'ind_var30_0',
#  'ind_var30',
#  'ind_var31_0',
#  'ind_var31',
#  'ind_var32_cte',
#  'ind_var32_0',
#  'ind_var32',
#  'ind_var33_0',
#  'ind_var33',
#  'ind_var34_0',
#  'ind_var34',
#  'ind_var37_cte',
#  'ind_var37_0',
#  'ind_var37',
#  'ind_var39_0',
#  'ind_var40_0',
#  'ind_var40',
#  'ind_var41_0',
#  'ind_var41',
#  'ind_var39',
#  'ind_var44_0',
#  'ind_var44',
#  'ind_var46_0',
#  'ind_var46',
#  'num_var1_0',
#  'num_var1',
#  'num_var4',
#  'num_var5_0',
#  'num_var5',
#  'num_var6_0',
#  'num_var6',
#  'num_var8_0',
#  'num_var8',
#  'num_var12_0',
#  'num_var12',
#  'num_var13_0',
#  'num_var13_corto_0',
#  'num_var13_corto',
#  'num_var13_largo_0',
#  'num_var13_largo',
#  'num_var13_medio_0',
#  'num_var13_medio',
#  'num_var13',
#  'num_var14_0',
#  'num_var14',
#  'num_var17_0',
#  'num_var17',
#  'num_var18_0',
#  'num_var18',
#  'num_var20_0',
#  'num_var20',
#  'num_var24_0',
#  'num_var24',
#  'num_var26_0',
#  'num_var26',
#  'num_var25_0',
#  'num_var25',
#  'num_op_var40_hace2',
#  'num_op_var40_hace3',
#  'num_op_var40_ult1',
#  'num_op_var40_ult3',
#  'num_op_var41_hace2',
#  'num_op_var41_hace3',
#  'num_op_var41_ult1',
#  'num_op_var41_ult3',
#  'num_op_var39_hace2',
#  'num_op_var39_hace3',
#  'num_op_var39_ult1',
#  'num_op_var39_ult3',
#  'num_var27_0',
#  'num_var28_0',
#  'num_var28',
#  'num_var27',
#  'num_var29_0',
#  'num_var29',
#  'num_var30_0',
#  'num_var30',
#  'num_var31_0',
#  'num_var31',
#  'num_var32_0',
#  'num_var32',
#  'num_var33_0',
#  'num_var33',
#  'num_var34_0',
#  'num_var34',
#  'num_var35',
#  'num_var37_med_ult2',
#  'num_var37_0',
#  'num_var37',
#  'num_var39_0',
#  'num_var40_0',
#  'num_var40',
#  'num_var41_0',
#  'num_var41',
#  'num_var39',
#  'num_var42_0',
#  'num_var42',
#  'num_var44_0',
#  'num_var44',
#  'num_var46_0',
#  'num_var46',
#  'saldo_var1',
#  'saldo_var5',
#  'saldo_var6',
#  'saldo_var8',
#  'saldo_var12',
#  'saldo_var13_corto',
#  'saldo_var13_largo',
#  'saldo_var13_medio',
#  'saldo_var13',
#  'saldo_var14',
#  'saldo_var17',
#  'saldo_var18',
#  'saldo_var20',
#  'saldo_var24',
#  'saldo_var26',
#  'saldo_var25',
#  'saldo_var28',
#  'saldo_var27',
#  'saldo_var29',
#  'saldo_var30',
#  'saldo_var31',
#  'saldo_var32',
#  'saldo_var33',
#  'saldo_var34',
#  'saldo_var37',
#  'saldo_var40',
#  'saldo_var41',
#  'saldo_var42',
#  'saldo_var44',
#  'saldo_var46',
#  'var36',
#  'delta_imp_amort_var18_1y3',
#  'delta_imp_amort_var34_1y3',
#  'delta_imp_aport_var13_1y3',
#  'delta_imp_aport_var17_1y3',
#  'delta_imp_aport_var33_1y3',
#  'delta_imp_compra_var44_1y3',
#  'delta_imp_reemb_var13_1y3',
#  'delta_imp_reemb_var17_1y3',
#  'delta_imp_reemb_var33_1y3',
#  'delta_imp_trasp_var17_in_1y3',
#  'delta_imp_trasp_var17_out_1y3',
#  'delta_imp_trasp_var33_in_1y3',
#  'delta_imp_trasp_var33_out_1y3',
#  'delta_imp_venta_var44_1y3',
#  'delta_num_aport_var13_1y3',
#  'delta_num_aport_var17_1y3',
#  'delta_num_aport_var33_1y3',
#  'delta_num_compra_var44_1y3',
#  'delta_num_reemb_var13_1y3',
#  'delta_num_reemb_var17_1y3',
#  'delta_num_reemb_var33_1y3',
#  'delta_num_trasp_var17_in_1y3',
#  'delta_num_trasp_var17_out_1y3',
#  'delta_num_trasp_var33_in_1y3',
#  'delta_num_trasp_var33_out_1y3',
#  'delta_num_venta_var44_1y3',
#  'imp_amort_var18_hace3',
#  'imp_amort_var18_ult1',
#  'imp_amort_var34_hace3',
#  'imp_amort_var34_ult1',
#  'imp_aport_var13_hace3',
#  'imp_aport_var13_ult1',
#  'imp_aport_var17_hace3',
#  'imp_aport_var17_ult1',
#  'imp_aport_var33_hace3',
#  'imp_aport_var33_ult1',
#  'imp_var7_emit_ult1',
#  'imp_var7_recib_ult1',
#  'imp_compra_var44_hace3',
#  'imp_compra_var44_ult1',
#  'imp_reemb_var13_hace3',
#  'imp_reemb_var13_ult1',
#  'imp_reemb_var17_hace3',
#  'imp_reemb_var17_ult1',
#  'imp_reemb_var33_hace3',
#  'imp_reemb_var33_ult1',
#  'imp_var43_emit_ult1',
#  'imp_trans_var37_ult1',
#  'imp_trasp_var17_in_hace3',
#  'imp_trasp_var17_in_ult1',
#  'imp_trasp_var17_out_hace3',
#  'imp_trasp_var17_out_ult1',
#  'imp_trasp_var33_in_hace3',
#  'imp_trasp_var33_in_ult1',
#  'imp_trasp_var33_out_hace3',
#  'imp_trasp_var33_out_ult1',
#  'imp_venta_var44_hace3',
#  'imp_venta_var44_ult1',
#  'ind_var7_emit_ult1',
#  'ind_var7_recib_ult1',
#  'ind_var10_ult1',
#  'ind_var10cte_ult1',
#  'ind_var9_cte_ult1',
#  'ind_var9_ult1',
#  'ind_var43_emit_ult1',
#  'ind_var43_recib_ult1',
#  'var21',
#  'num_var2_0_ult1',
#  'num_var2_ult1',
#  'num_aport_var13_hace3',
#  'num_aport_var13_ult1',
#  'num_aport_var17_hace3',
#  'num_aport_var17_ult1',
#  'num_aport_var33_hace3',
#  'num_aport_var33_ult1',
#  'num_var7_emit_ult1',
#  'num_var7_recib_ult1',
#  'num_compra_var44_hace3',
#  'num_compra_var44_ult1',
#  'num_ent_var16_ult1',
#  'num_var22_hace2',
#  'num_var22_hace3',
#  'num_var22_ult1',
#  'num_var22_ult3',
#  'num_med_var22_ult3',
#  'num_med_var45_ult3',
#  'num_meses_var5_ult3',
#  'num_meses_var8_ult3',
#  'num_meses_var12_ult3',
#  'num_meses_var13_corto_ult3',
#  'num_meses_var13_largo_ult3',
#  'num_meses_var13_medio_ult3',
#  'num_meses_var17_ult3',
#  'num_meses_var29_ult3',
#  'num_meses_var33_ult3',
#  'num_meses_var39_vig_ult3',
#  'num_meses_var44_ult3',
#  'num_op_var39_comer_ult1',
#  'num_op_var39_comer_ult3',
#  'num_op_var40_comer_ult1',
#  'num_op_var40_comer_ult3',
#  'num_op_var40_efect_ult1',
#  'num_op_var40_efect_ult3',
#  'num_op_var41_comer_ult1',
#  'num_op_var41_comer_ult3',
#  'num_op_var41_efect_ult1',
#  'num_op_var41_efect_ult3',
#  'num_op_var39_efect_ult1',
#  'num_op_var39_efect_ult3',
#  'num_reemb_var13_hace3',
#  'num_reemb_var13_ult1',
#  'num_reemb_var17_hace3',
#  'num_reemb_var17_ult1',
#  'num_reemb_var33_hace3',
#  'num_reemb_var33_ult1',
#  'num_sal_var16_ult1',
#  'num_var43_emit_ult1',
#  'num_var43_recib_ult1',
#  'num_trasp_var11_ult1',
#  'num_trasp_var17_in_hace3',
#  'num_trasp_var17_in_ult1',
#  'num_trasp_var17_out_hace3',
#  'num_trasp_var17_out_ult1',
#  'num_trasp_var33_in_hace3',
#  'num_trasp_var33_in_ult1',
#  'num_trasp_var33_out_hace3',
#  'num_trasp_var33_out_ult1',
#  'num_venta_var44_hace3',
#  'num_venta_var44_ult1',
#  'num_var45_hace2',
#  'num_var45_hace3',
#  'num_var45_ult1',
#  'num_var45_ult3',
#  'saldo_var2_ult1',
#  'saldo_medio_var5_hace2',
#  'saldo_medio_var5_hace3',
#  'saldo_medio_var5_ult1',
#  'saldo_medio_var5_ult3',
#  'saldo_medio_var8_hace2',
#  'saldo_medio_var8_hace3',
#  'saldo_medio_var8_ult1',
#  'saldo_medio_var8_ult3',
#  'saldo_medio_var12_hace2',
#  'saldo_medio_var12_hace3',
#  'saldo_medio_var12_ult1',
#  'saldo_medio_var12_ult3',
#  'saldo_medio_var13_corto_hace2',
#  'saldo_medio_var13_corto_hace3',
#  'saldo_medio_var13_corto_ult1',
#  'saldo_medio_var13_corto_ult3',
#  'saldo_medio_var13_largo_hace2',
#  'saldo_medio_var13_largo_hace3',
#  'saldo_medio_var13_largo_ult1',
#  'saldo_medio_var13_largo_ult3',
#  'saldo_medio_var13_medio_hace2',
#  'saldo_medio_var13_medio_hace3',
#  'saldo_medio_var13_medio_ult1',
#  'saldo_medio_var13_medio_ult3',
#  'saldo_medio_var17_hace2',
#  'saldo_medio_var17_hace3',
#  'saldo_medio_var17_ult1',
#  'saldo_medio_var17_ult3',
#  'saldo_medio_var29_hace2',
#  'saldo_medio_var29_hace3',
#  'saldo_medio_var29_ult1',
#  'saldo_medio_var29_ult3',
#  'saldo_medio_var33_hace2',
#  'saldo_medio_var33_hace3',
#  'saldo_medio_var33_ult1',
#  'saldo_medio_var33_ult3',
#  'saldo_medio_var44_hace2',
#  'saldo_medio_var44_hace3',
#  'saldo_medio_var44_ult1',
#  'saldo_medio_var44_ult3',
#  'var38']

# %%
# 방법 1: 모든 컬럼의 value_counts() 출력 (상위 10개)
print("="*80)
print("각 컬럼별 Value Counts (상위 10개)")
print("="*80)

for col in myCols:
    if col in df.columns:
        print(f"\n[{col}]")
        print(df[col].value_counts().head(10))
        print(f"고유값 개수: {df[col].nunique()}")
        print("-" * 40)
    else:
        print(f"\n[{col}] - 컬럼이 존재하지 않습니다.")
# Out:
# ================================================================================
# 각 컬럼별 Value Counts (상위 10개)
# ================================================================================
#
# [imp_amort_var18_ult1]
# imp_amort_var18_ult1
# 0.00        76018
# 15691.80        1
# 1883.22         1
# Name: count, dtype: int64
# 고유값 개수: 3
# ----------------------------------------
#
# [imp_amort_var34_hace3]
# imp_amort_var34_hace3
# 0    76020
# Name: count, dtype: int64
# 고유값 개수: 1
# ----------------------------------------
#
# [imp_amort_var34_ult1]
# imp_amort_var34_ult1
# 0.00       76018
# 1096.02        1
# 276.24         1
# Name: count, dtype: int64
# 고유값 개수: 3
# ----------------------------------------
#
# [imp_aport_var13_hace3]
# imp_aport_var13_hace3
# 0.0         74314
# 90000.0        84
# 150000.0       81
# 30000.0        68
# 300000.0       66
# 60000.0        65
# 75000.0        63
# 120000.0       60
# 180000.0       51
# 45000.0        51
# Name: count, dtype: int64
# 고유값 개수: 425
# ----------------------------------------
#
# [imp_aport_var13_ult1]
# imp_aport_var13_ult1
# 0.0         75619
# 90000.0        23
# 300000.0       17
# 150000.0       16
# 15000.0        13
# 75000.0        13
# 180000.0       13
# 36000.0        12
# 60000.0        11
# 30000.0        10
# Name: count, dtype: int64
# 고유값 개수: 182
# ----------------------------------------
#
# [imp_aport_var17_hace3]
# imp_aport_var17_hace3
# 0.00          75998
# 30000.00          2
# 3000.00           2
# 120000.00         2
# 37500.00          1
# 1815.00           1
# 96781.44          1
# 6083691.87        1
# 45741.48          1
# 22793.16          1
# Name: count, dtype: int64
# 고유값 개수: 20
# ----------------------------------------
#
# [imp_aport_var17_ult1]
# imp_aport_var17_ult1
# 0.00         75976
# 30000.00         3
# 3000.00          2
# 6129.90          1
# 144302.34        1
# 12000.00         1
# 60778.41         1
# 432457.32        1
# 24000.00         1
# 14356.26         1
# Name: count, dtype: int64
# 고유값 개수: 42
# ----------------------------------------
#
# [imp_aport_var33_hace3]
# imp_aport_var33_hace3
# 0        75997
# 15000        4
# 1500         3
# 9000         2
# 18000        2
# 7500         2
# 4500         1
# 12600        1
# 7530         1
# 150          1
# Name: count, dtype: int64
# 고유값 개수: 16
# ----------------------------------------
#
# [imp_aport_var33_ult1]
# imp_aport_var33_ult1
# 0       76013
# 450         2
# 300         2
# 750         1
# 1260        1
# 150         1
# Name: count, dtype: int64
# 고유값 개수: 6
# ----------------------------------------
#
# [imp_var7_emit_ult1]
# imp_var7_emit_ult1
# 0.00         76017
# 145384.92        1
# 18000.00         1
# 43500.00         1
# Name: count, dtype: int64
# 고유값 개수: 4
# ----------------------------------------
#
# [imp_var7_recib_ult1]
# imp_var7_recib_ult1
# 0.0         75815
# 90000.0         3
# 75000.0         3
# 45000.0         3
# 3000.0          3
# 900.0           3
# 210000.0        3
# 600.0           2
# 300000.0        2
# 120000.0        2
# Name: count, dtype: int64
# 고유값 개수: 184
# ----------------------------------------
#
# [imp_compra_var44_hace3]
# imp_compra_var44_hace3
# 0.00        75988
# 6679.05         1
# 41801.64        1
# 3019.50         1
# 17113.80        1
# 13568.40        1
# 18203.52        1
# 27.30           1
# 19308.24        1
# 10597.44        1
# Name: count, dtype: int64
# 고유값 개수: 33
# ----------------------------------------
#
# [imp_compra_var44_ult1]
# imp_compra_var44_ult1
# 0.00        75936
# 15752.88        1
# 3050.79         1
# 799.26          1
# 1495.02         1
# 167.61          1
# 14189.52        1
# 23262.96        1
# 560.34          1
# 5854.80         1
# Name: count, dtype: int64
# 고유값 개수: 85
# ----------------------------------------
#
# [imp_reemb_var13_hace3]
# imp_reemb_var13_hace3
# 0    76020
# Name: count, dtype: int64
# 고유값 개수: 1
# ----------------------------------------
#
# [imp_reemb_var13_ult1]
# imp_reemb_var13_ult1
# 0.0         75982
# 90000.0         3
# 18000.0         3
# 180000.0        2
# 6000.0          2
# 66000.0         1
# 15000.0         1
# 51000.0         1
# 111000.0        1
# 270000.0        1
# Name: count, dtype: int64
# 고유값 개수: 33
# ----------------------------------------
#
# [imp_reemb_var17_hace3]
# imp_reemb_var17_hace3
# 0.00        76019
# 12027.15        1
# Name: count, dtype: int64
# 고유값 개수: 2
# ----------------------------------------
#
# [imp_reemb_var17_ult1]
# imp_reemb_var17_ult1
# 0.00        76000
# 37035.75        2
# 6098.28         1
# 56395.56        1
# 26571.81        1
# 4149.39         1
# 69620.10        1
# 69622.29        1
# 3059.52         1
# 36000.00        1
# Name: count, dtype: int64
# 고유값 개수: 20
# ----------------------------------------
#
# [imp_reemb_var33_hace3]
# imp_reemb_var33_hace3
# 0    76020
# Name: count, dtype: int64
# 고유값 개수: 1
# ----------------------------------------
#
# [imp_reemb_var33_ult1]
# imp_reemb_var33_ult1
# 0       76019
# 1200        1
# Name: count, dtype: int64
# 고유값 개수: 2
# ----------------------------------------
#
# [imp_var43_emit_ult1]
# imp_var43_emit_ult1
# 0.0       70958
# 3000.0      117
# 300.0       114
# 1500.0      107
# 900.0        97
# 90.0         94
# 600.0        87
# 150.0        83
# 30.0         80
# 1200.0       74
# Name: count, dtype: int64
# 고유값 개수: 2342
# ----------------------------------------
#
# [imp_trans_var37_ult1]
# imp_trans_var37_ult1
# 0.0       66190
# 300.0       408
# 600.0       320
# 1500.0      275
# 150.0       262
# 900.0       245
# 3000.0      233
# 1200.0      180
# 450.0       144
# 1800.0      143
# Name: count, dtype: int64
# 고유값 개수: 3831
# ----------------------------------------
#
# [imp_trasp_var17_in_hace3]
# imp_trasp_var17_in_hace3
# 0.00        76018
# 96781.44        1
# 45741.48        1
# Name: count, dtype: int64
# 고유값 개수: 3
# ----------------------------------------
#
# [imp_trasp_var17_in_ult1]
# imp_trasp_var17_in_ult1
# 0.00         76016
# 14356.26         1
# 2999.82          1
# 39927.15         1
# 133730.58        1
# Name: count, dtype: int64
# 고유값 개수: 5
# ----------------------------------------
#
# [imp_trasp_var17_out_hace3]
# imp_trasp_var17_out_hace3
# 0    76020
# Name: count, dtype: int64
# 고유값 개수: 1
# ----------------------------------------
#
# [imp_trasp_var17_out_ult1]
# imp_trasp_var17_out_ult1
# 0.00        76016
# 69622.29        1
# 3059.52         1
# 69599.01        1
# 3192.27         1
# Name: count, dtype: int64
# 고유값 개수: 5
# ----------------------------------------
#
# [imp_trasp_var33_in_hace3]
# imp_trasp_var33_in_hace3
# 0.00        76014
# 49581.27        1
# 25501.80        1
# 25920.03        1
# 33744.48        1
# 44251.08        1
# 33079.83        1
# Name: count, dtype: int64
# 고유값 개수: 7
# ----------------------------------------
#
# [imp_trasp_var33_in_ult1]
# imp_trasp_var33_in_ult1
# 0.00        76015
# 2545.65         1
# 5400.00         1
# 13207.32        1
# 2596.53         1
# 174.09          1
# Name: count, dtype: int64
# 고유값 개수: 6
# ----------------------------------------
#
# [imp_trasp_var33_out_hace3]
# imp_trasp_var33_out_hace3
# 0    76020
# Name: count, dtype: int64
# 고유값 개수: 1
# ----------------------------------------
#
# [imp_trasp_var33_out_ult1]
# imp_trasp_var33_out_ult1
# 0       76019
# 3000        1
# Name: count, dtype: int64
# 고유값 개수: 2
# ----------------------------------------
#
# [imp_venta_var44_hace3]
# imp_venta_var44_hace3
# 0.00         76017
# 23.16            1
# 209834.40        1
# 78040.59         1
# Name: count, dtype: int64
# 고유값 개수: 4
# ----------------------------------------
#
# [imp_venta_var44_ult1]
# imp_venta_var44_ult1
# 0.00         75976
# 18944.64         1
# 7267.05          1
# 388.08           1
# 735.33           1
# 21948.36         1
# 3127.02          1
# 17122.50         1
# 125480.49        1
# 450.99           1
# Name: count, dtype: int64
# 고유값 개수: 45
# ----------------------------------------
#
# [ind_var7_emit_ult1]
# ind_var7_emit_ult1
# 0    76017
# 1        3
# Name: count, dtype: int64
# 고유값 개수: 2
# ----------------------------------------
#
# [ind_var7_recib_ult1]
# ind_var7_recib_ult1
# 0    75815
# 1      205
# Name: count, dtype: int64
# 고유값 개수: 2
# ----------------------------------------
#
# [ind_var10_ult1]
# ind_var10_ult1
# 0    69872
# 1     6148
# Name: count, dtype: int64
# 고유값 개수: 2
# ----------------------------------------
#
# [ind_var10cte_ult1]
# ind_var10cte_ult1
# 0    69014
# 1     7006
# Name: count, dtype: int64
# 고유값 개수: 2
# ----------------------------------------
#
# [ind_var9_cte_ult1]
# ind_var9_cte_ult1
# 0    68656
# 1     7364
# Name: count, dtype: int64
# 고유값 개수: 2
# ----------------------------------------
#
# [ind_var9_ult1]
# ind_var9_ult1
# 0    69489
# 1     6531
# Name: count, dtype: int64
# 고유값 개수: 2
# ----------------------------------------
#
# [ind_var43_emit_ult1]
# ind_var43_emit_ult1
# 0    70958
# 1     5062
# Name: count, dtype: int64
# 고유값 개수: 2
# ----------------------------------------
#
# [ind_var43_recib_ult1]
# ind_var43_recib_ult1
# 0    66190
# 1     9830
# Name: count, dtype: int64
# 고유값 개수: 2
# ----------------------------------------
#
# [var21]
# var21
# 0       75152
# 900       236
# 1800      206
# 4500       96
# 3000       84
# 7200       62
# 3600       52
# 1500       31
# 6000       27
# 2700       26
# Name: count, dtype: int64
# 고유값 개수: 24
# ----------------------------------------
#
# [num_var2_0_ult1]
# num_var2_0_ult1
# 0    76020
# Name: count, dtype: int64
# 고유값 개수: 1
# ----------------------------------------
#
# [num_var2_ult1]
# num_var2_ult1
# 0    76020
# Name: count, dtype: int64
# 고유값 개수: 1
# ----------------------------------------
#
# [num_aport_var13_hace3]
# num_aport_var13_hace3
# 0     74314
# 3      1565
# 6        97
# 9        25
# 12       14
# 24        2
# 18        2
# 15        1
# Name: count, dtype: int64
# 고유값 개수: 8
# ----------------------------------------
#
# [num_aport_var13_ult1]
# num_aport_var13_ult1
# 0     75619
# 3       373
# 6        17
# 9         6
# 12        3
# 30        1
# 24        1
# Name: count, dtype: int64
# 고유값 개수: 7
# ----------------------------------------
#
# [num_aport_var17_hace3]
# num_aport_var17_hace3
# 0     75998
# 3        12
# 6         6
# 12        3
# 9         1
# Name: count, dtype: int64
# 고유값 개수: 5
# ----------------------------------------
#
# [num_aport_var17_ult1]
# num_aport_var17_ult1
# 0     75976
# 3        23
# 6        12
# 9         3
# 12        3
# 18        1
# 15        1
# 21        1
# Name: count, dtype: int64
# 고유값 개수: 8
# ----------------------------------------
#
# [num_aport_var33_hace3]
# num_aport_var33_hace3
# 0     75997
# 3        21
# 12        1
# 6         1
# Name: count, dtype: int64
# 고유값 개수: 4
# ----------------------------------------
#
# [num_aport_var33_ult1]
# num_aport_var33_ult1
# 0    76013
# 3        6
# 6        1
# Name: count, dtype: int64
# 고유값 개수: 3
# ----------------------------------------
#
# [num_var7_emit_ult1]
# num_var7_emit_ult1
# 0    76017
# 3        3
# Name: count, dtype: int64
# 고유값 개수: 2
# ----------------------------------------
#
# [num_var7_recib_ult1]
# num_var7_recib_ult1
# 0     75815
# 3       166
# 6        30
# 9         5
# 12        3
# 24        1
# Name: count, dtype: int64
# 고유값 개수: 6
# ----------------------------------------
#
# [num_compra_var44_hace3]
# num_compra_var44_hace3
# 0    75988
# 3       20
# 6        9
# 9        3
# Name: count, dtype: int64
# 고유값 개수: 4
# ----------------------------------------
#
# [num_compra_var44_ult1]
# num_compra_var44_ult1
# 0     75936
# 3        46
# 6        18
# 9         6
# 24        4
# 12        3
# 15        3
# 18        2
# 21        1
# 39        1
# Name: count, dtype: int64
# 고유값 개수: 10
# ----------------------------------------
#
# [num_ent_var16_ult1]
# num_ent_var16_ult1
# 0     72301
# 3      3043
# 6       483
# 9       115
# 12       47
# 15       12
# 18        7
# 21        4
# 30        3
# 27        2
# Name: count, dtype: int64
# 고유값 개수: 13
# ----------------------------------------
#
# [num_var22_hace2]
# num_var22_hace2
# 0     60541
# 3      7455
# 6      3856
# 9      1916
# 12     1030
# 15      548
# 18      269
# 21      178
# 24       99
# 27       46
# Name: count, dtype: int64
# 고유값 개수: 22
# ----------------------------------------
#
# [num_var22_hace3]
# num_var22_hace3
# 0     61880
# 3      6934
# 6      3345
# 9      1669
# 12     1021
# 15      543
# 18      288
# 21      157
# 24       71
# 27       48
# Name: count, dtype: int64
# 고유값 개수: 19
# ----------------------------------------
#
# [num_var22_ult1]
# num_var22_ult1
# 0     67953
# 3      4832
# 6      1829
# 9       734
# 12      320
# 15      174
# 18       76
# 21       40
# 24       21
# 27       15
# Name: count, dtype: int64
# 고유값 개수: 18
# ----------------------------------------
#
# [num_var22_ult3]
# num_var22_ult3
# 0     49954
# 3      9176
# 6      5636
# 9      3758
# 12     2534
# 15     1689
# 18     1084
# 21      711
# 24      476
# 27      300
# Name: count, dtype: int64
# 고유값 개수: 33
# ----------------------------------------
#
# [num_med_var22_ult3]
# num_med_var22_ult3
# 0     64766
# 3      7981
# 6      2271
# 9       684
# 12      199
# 15       65
# 18       28
# 21        8
# 24        7
# 27        4
# Name: count, dtype: int64
# 고유값 개수: 15
# ----------------------------------------
#
# [num_med_var45_ult3]
# num_med_var45_ult3
# 0     51408
# 3      8258
# 6      4650
# 9      2951
# 12     2124
# 15     1473
# 18     1013
# 21      784
# 24      597
# 27      475
# Name: count, dtype: int64
# 고유값 개수: 71
# ----------------------------------------
#
# [num_meses_var5_ult3]
# num_meses_var5_ult3
# 3    42838
# 0    20546
# 2     9368
# 1     3268
# Name: count, dtype: int64
# 고유값 개수: 4
# ----------------------------------------
#
# [num_meses_var8_ult3]
# num_meses_var8_ult3
# 0    73805
# 2      910
# 1      830
# 3      475
# Name: count, dtype: int64
# 고유값 개수: 4
# ----------------------------------------
#
# [num_meses_var12_ult3]
# num_meses_var12_ult3
# 0    72537
# 2     1711
# 3     1282
# 1      490
# Name: count, dtype: int64
# 고유값 개수: 4
# ----------------------------------------
#
# [num_meses_var13_corto_ult3]
# num_meses_var13_corto_ult3
# 0    72760
# 2     1596
# 3     1332
# 1      332
# Name: count, dtype: int64
# 고유값 개수: 4
# ----------------------------------------
#
# [num_meses_var13_largo_ult3]
# num_meses_var13_largo_ult3
# 0    75477
# 3      296
# 2      188
# 1       59
# Name: count, dtype: int64
# 고유값 개수: 4
# ----------------------------------------
#
# [num_meses_var13_medio_ult3]
# num_meses_var13_medio_ult3
# 0    76018
# 2        2
# Name: count, dtype: int64
# 고유값 개수: 2
# ----------------------------------------
#
# [num_meses_var17_ult3]
# num_meses_var17_ult3
# 0    75897
# 2       72
# 1       36
# 3       15
# Name: count, dtype: int64
# 고유값 개수: 4
# ----------------------------------------
#
# [num_meses_var29_ult3]
# num_meses_var29_ult3
# 0    76015
# 2        3
# 1        2
# Name: count, dtype: int64
# 고유값 개수: 3
# ----------------------------------------
#
# [num_meses_var33_ult3]
# num_meses_var33_ult3
# 0    75972
# 3       24
# 2       19
# 1        5
# Name: count, dtype: int64
# 고유값 개수: 4
# ----------------------------------------
#
# [num_meses_var39_vig_ult3]
# num_meses_var39_vig_ult3
# 2    54536
# 1    10974
# 0    10164
# 3      346
# Name: count, dtype: int64
# 고유값 개수: 4
# ----------------------------------------
#
# [num_meses_var44_ult3]
# num_meses_var44_ult3
# 0    75877
# 2       67
# 1       45
# 3       31
# Name: count, dtype: int64
# 고유값 개수: 4
# ----------------------------------------
#
# [num_op_var39_comer_ult1]
# num_op_var39_comer_ult1
# 0     66075
# 3      2641
# 6      1475
# 9      1036
# 12      781
# 15      677
# 18      553
# 21      422
# 24      346
# 27      308
# Name: count, dtype: int64
# 고유값 개수: 63
# ----------------------------------------
#
# [num_op_var39_comer_ult3]
# num_op_var39_comer_ult3
# 0     64330
# 3      2645
# 6      1549
# 9      1125
# 12      818
# 15      679
# 18      594
# 21      499
# 24      411
# 27      351
# Name: count, dtype: int64
# 고유값 개수: 92
# ----------------------------------------
#
# [num_op_var40_comer_ult1]
# num_op_var40_comer_ult1
# 0     75725
# 3        74
# 6        42
# 9        35
# 15       20
# 12       20
# 18       18
# 24       15
# 21       11
# 27       11
# Name: count, dtype: int64
# 고유값 개수: 34
# ----------------------------------------
#
# [num_op_var40_comer_ult3]
# num_op_var40_comer_ult3
# 0     75672
# 3        71
# 6        48
# 9        30
# 12       22
# 15       21
# 18       16
# 24       14
# 21       12
# 27       11
# Name: count, dtype: int64
# 고유값 개수: 47
# ----------------------------------------

# %%
# 방법 2: 요약 정보 (DataFrame으로)
print(f'\n{"="*102}')
print("전체 요약".center(102))
print("="*102)

summary_data = []
for col in myCols:
    if col in df.columns:
        zero_count = (df[col] == 0).sum()
        mode_freq = df[col].value_counts().iloc[0] if len(df[col]) > 0 else 0
        
        summary_data.append({
            'ColumnName': col,  # 컬럼명
            'na_Sum': df[col].isna().sum(),  # 결측치_개수
            'nUnique': df[col].nunique(),  # 고유값_개수
            'mode': df[col].mode()[0] if len(df[col].mode()) > 0 else None,  # 최빈값
            'modeFreq': mode_freq,  # 최빈값_빈도
            'modeFreqRate': f"{(mode_freq / len(df) * 100):.2f}%",  # 최빈값_빈도_비율
            'zero_count': zero_count,  # 0값_개수
            'zero_count_rate': f"{(zero_count / len(df) * 100):.2f}%"  # 0값_비율
        })

summary_df = pd.DataFrame(summary_data)
print(summary_df.to_string(index=False))
# Out:
# ======================================================================================================
#                                                 전체 요약
# ======================================================================================================
#                 ColumnName  na_Sum  nUnique  mode  modeFreq modeFreqRate  zero_count zero_count_rate
#       imp_amort_var18_ult1       0        3   0.0     76018      100.00%       76018         100.00%
#      imp_amort_var34_hace3       0        1   0.0     76020      100.00%       76020         100.00%
#       imp_amort_var34_ult1       0        3   0.0     76018      100.00%       76018         100.00%
#      imp_aport_var13_hace3       0      425   0.0     74314       97.76%       74314          97.76%
#       imp_aport_var13_ult1       0      182   0.0     75619       99.47%       75619          99.47%
#      imp_aport_var17_hace3       0       20   0.0     75998       99.97%       75998          99.97%
#       imp_aport_var17_ult1       0       42   0.0     75976       99.94%       75976          99.94%
#      imp_aport_var33_hace3       0       16   0.0     75997       99.97%       75997          99.97%
#       imp_aport_var33_ult1       0        6   0.0     76013       99.99%       76013          99.99%
#         imp_var7_emit_ult1       0        4   0.0     76017      100.00%       76017         100.00%
#        imp_var7_recib_ult1       0      184   0.0     75815       99.73%       75815          99.73%
#     imp_compra_var44_hace3       0       33   0.0     75988       99.96%       75988          99.96%
#      imp_compra_var44_ult1       0       85   0.0     75936       99.89%       75936          99.89%
#      imp_reemb_var13_hace3       0        1   0.0     76020      100.00%       76020         100.00%
#       imp_reemb_var13_ult1       0       33   0.0     75982       99.95%       75982          99.95%
#      imp_reemb_var17_hace3       0        2   0.0     76019      100.00%       76019         100.00%
#       imp_reemb_var17_ult1       0       20   0.0     76000       99.97%       76000          99.97%
#      imp_reemb_var33_hace3       0        1   0.0     76020      100.00%       76020         100.00%
#       imp_reemb_var33_ult1       0        2   0.0     76019      100.00%       76019         100.00%
#        imp_var43_emit_ult1       0     2342   0.0     70958       93.34%       70958          93.34%
#       imp_trans_var37_ult1       0     3831   0.0     66190       87.07%       66190          87.07%
#   imp_trasp_var17_in_hace3       0        3   0.0     76018      100.00%       76018         100.00%
#    imp_trasp_var17_in_ult1       0        5   0.0     76016       99.99%       76016          99.99%
#  imp_trasp_var17_out_hace3       0        1   0.0     76020      100.00%       76020         100.00%
#   imp_trasp_var17_out_ult1       0        5   0.0     76016       99.99%       76016          99.99%
#   imp_trasp_var33_in_hace3       0        7   0.0     76014       99.99%       76014          99.99%
#    imp_trasp_var33_in_ult1       0        6   0.0     76015       99.99%       76015          99.99%
#  imp_trasp_var33_out_hace3       0        1   0.0     76020      100.00%       76020         100.00%
#   imp_trasp_var33_out_ult1       0        2   0.0     76019      100.00%       76019         100.00%
#      imp_venta_var44_hace3       0        4   0.0     76017      100.00%       76017         100.00%
#       imp_venta_var44_ult1       0       45   0.0     75976       99.94%       75976          99.94%
#         ind_var7_emit_ult1       0        2   0.0     76017      100.00%       76017         100.00%
#        ind_var7_recib_ult1       0        2   0.0     75815       99.73%       75815          99.73%
#             ind_var10_ult1       0        2   0.0     69872       91.91%       69872          91.91%
#          ind_var10cte_ult1       0        2   0.0     69014       90.78%       69014          90.78%
#          ind_var9_cte_ult1       0        2   0.0     68656       90.31%       68656          90.31%
#              ind_var9_ult1       0        2   0.0     69489       91.41%       69489          91.41%
#        ind_var43_emit_ult1       0        2   0.0     70958       93.34%       70958          93.34%
#       ind_var43_recib_ult1       0        2   0.0     66190       87.07%       66190          87.07%
#                      var21       0       24   0.0     75152       98.86%       75152          98.86%
#            num_var2_0_ult1       0        1   0.0     76020      100.00%       76020         100.00%
#              num_var2_ult1       0        1   0.0     76020      100.00%       76020         100.00%
#      num_aport_var13_hace3       0        8   0.0     74314       97.76%       74314          97.76%
#       num_aport_var13_ult1       0        7   0.0     75619       99.47%       75619          99.47%
#      num_aport_var17_hace3       0        5   0.0     75998       99.97%       75998          99.97%
#       num_aport_var17_ult1       0        8   0.0     75976       99.94%       75976          99.94%
#      num_aport_var33_hace3       0        4   0.0     75997       99.97%       75997          99.97%
#       num_aport_var33_ult1       0        3   0.0     76013       99.99%       76013          99.99%
#         num_var7_emit_ult1       0        2   0.0     76017      100.00%       76017         100.00%
#        num_var7_recib_ult1       0        6   0.0     75815       99.73%       75815          99.73%
#     num_compra_var44_hace3       0        4   0.0     75988       99.96%       75988          99.96%
#      num_compra_var44_ult1       0       10   0.0     75936       99.89%       75936          99.89%
#         num_ent_var16_ult1       0       13   0.0     72301       95.11%       72301          95.11%
#            num_var22_hace2       0       22   0.0     60541       79.64%       60541          79.64%
#            num_var22_hace3       0       19   0.0     61880       81.40%       61880          81.40%
#             num_var22_ult1       0       18   0.0     67953       89.39%       67953          89.39%
#             num_var22_ult3       0       33   0.0     49954       65.71%       49954          65.71%
#         num_med_var22_ult3       0       15   0.0     64766       85.20%       64766          85.20%
#         num_med_var45_ult3       0       71   0.0     51408       67.62%       51408          67.62%
#        num_meses_var5_ult3       0        4   3.0     42838       56.35%       20546          27.03%
#        num_meses_var8_ult3       0        4   0.0     73805       97.09%       73805          97.09%
#       num_meses_var12_ult3       0        4   0.0     72537       95.42%       72537          95.42%
# num_meses_var13_corto_ult3       0        4   0.0     72760       95.71%       72760          95.71%
# num_meses_var13_largo_ult3       0        4   0.0     75477       99.29%       75477          99.29%
# num_meses_var13_medio_ult3       0        2   0.0     76018      100.00%       76018         100.00%
#       num_meses_var17_ult3       0        4   0.0     75897       99.84%       75897          99.84%
#       num_meses_var29_ult3       0        3   0.0     76015       99.99%       76015          99.99%
#       num_meses_var33_ult3       0        4   0.0     75972       99.94%       75972          99.94%
#   num_meses_var39_vig_ult3       0        4   2.0     54536       71.74%       10164          13.37%
#       num_meses_var44_ult3       0        4   0.0     75877       99.81%       75877          99.81%
#    num_op_var39_comer_ult1       0       63   0.0     66075       86.92%       66075          86.92%
#    num_op_var39_comer_ult3       0       92   0.0     64330       84.62%       64330          84.62%
#    num_op_var40_comer_ult1       0       34   0.0     75725       99.61%       75725          99.61%
#    num_op_var40_comer_ult3       0       47   0.0     75672       99.54%       75672          99.54%

# %%
# 방법 3: 특정 컬럼만 선택해서 보기
print("\n" + "="*80)
print("특정 컬럼 상세 분석 예시")
print("="*80)

# 예: 처음 3개 컬럼만 상세 분석
for col in myCols[:3]:
    if col in df.columns:
        print(f"\n[{col}] 전체 Value Counts:")
        vc = df[col].value_counts()
        print(vc)
        print(f"\n비율:")
        print(df[col].value_counts(normalize=True).head(10))
# Out:
# ================================================================================
# 특정 컬럼 상세 분석 예시
# ================================================================================
#
# [imp_amort_var18_ult1] 전체 Value Counts:
# imp_amort_var18_ult1
# 0.00        76018
# 15691.80        1
# 1883.22         1
# Name: count, dtype: int64
#
# 비율:
# imp_amort_var18_ult1
# 0.00        0.999974
# 15691.80    0.000013
# 1883.22     0.000013
# Name: proportion, dtype: float64
#
# [imp_amort_var34_hace3] 전체 Value Counts:
# imp_amort_var34_hace3
# 0    76020
# Name: count, dtype: int64
#
# 비율:
# imp_amort_var34_hace3
# 0    1.0
# Name: proportion, dtype: float64
#
# [imp_amort_var34_ult1] 전체 Value Counts:
# imp_amort_var34_ult1
# 0.00       76018
# 1096.02        1
# 276.24         1
# Name: count, dtype: int64
#
# 비율:
# imp_amort_var34_ult1
# 0.00       0.999974
# 1096.02    0.000013
# 276.24     0.000013
# Name: proportion, dtype: float64

# %%
# import matplotlib.pyplot as plot
# import seaborn as sns 

# sns.countplot(x="target", data=df['TARGET'].value_counts())
# plt.show()

# df['TARGET'].value_counts()

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

# TARGET value_counts 확인
print(f"\nTARGET Value Counts: {df['TARGET'].value_counts()}")
print(f"\nTARGET 비율: {df['TARGET'].value_counts(normalize=True)}")

# 시각화
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# 방법 1: countplot
sns.countplot(x='TARGET', data=df, ax=axes[0])
axes[0].set_title('TARGET 분포 (Count)', fontsize=14, fontweight='bold')
axes[0].set_xlabel('TARGET')
axes[0].set_ylabel('Count')

# 막대 위에 숫자 표시
for container in axes[0].containers:
    axes[0].bar_label(container, fmt='%d')

# 방법 2: pie chart (비율)
target_counts = df['TARGET'].value_counts()
axes[1].pie(target_counts, labels=target_counts.index, autopct='%1.2f%%', startangle=90)
axes[1].set_title('TARGET 분포 (비율)', fontsize=14, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# TARGET Value Counts: TARGET
# 0    73012
# 1     3008
# Name: count, dtype: int64
#
# TARGET 비율: TARGET
# 0    0.960431
# 1    0.039569
# Name: proportion, dtype: float64
