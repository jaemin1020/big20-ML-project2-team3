# %%
# 12.10 report 정리용
  # 1. 기본: df = load_results_to_df('../results')
  # 2. 빠른 리포트: quick_report('../results', top_n=10)
  # 3. 특정 모델 비교: compare_models(df, ['lgb', 'xgb', 'stacking'])
  # 4. Kaggle 제출: export_for_kaggle(df, 'stacking')

# %%
import sys, os
# 프로젝트 루트 추가 (hyperopt_search.py 임포트용)
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
    
from utils.results_report import load_results_to_df, quick_report, compare_models, export_for_kaggle
# Out:
# ✅ result_report.py 로드 완료!
#
# 사용법:
#   1. 기본: df = load_results_to_df('../results')
#   2. 빠른 리포트: quick_report('../results', top_n=10)
#   3. 특정 모델 비교: compare_models(df, ['lgb', 'xgb', 'stacking'])
#   4. Kaggle 제출: export_for_kaggle(df, 'stacking')

# %%
#df = load_results_to_df()

# %%
quick_report('../results', top_n=10)
# Out:
# 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀
#   Mercari Price Prediction - Quick Report
# 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀
#
# 📂 총 64개 JSON 파일 발견
# 🚫 제외 패턴: ['cache', 'submission', 'residual_samples', 'trials', 'best_params', 'metrics_summary']
#
# ✅ AutoGluon_FastText_metrics
# ✅ blended_R2_20251205_170940_metrics
# ✅ blended_R2_20251205_170940_metrics
# ✅ blended_R2_latest_metrics
# ✅ blended_R2_latest_metrics
# ✅ CatBoostRegressor_metrics
# ✅ LGBMRegressor_reg_result
# ✅ manual_ensemble_top3_metrics
# ✅ mercari_best_bert_metrics
# ✅ mercari_best_bert_metrics
# ✅ mercari_best_fasttext_metrics
# ✅ mercari_best_glove_metrics
# ✅ mercari_best_metrics
# ✅ mercari_best_metrics_word2vec
# ✅ mercari_best_tfidf_metrics
# ✅ mercari_best_word2vec_metrics
# ✅ PyCaret_FastText_metrics
# ✅ RandomForestRegressor_metrics
# ✅ RandomForestRegressor_metrics
# ✅ Ridge_metrics
# ✅ Ridge_metrics
# ✅ Ridge_metrics
# ✅ Ridge_metrics
# ✅ VotingRegressor_metrics
# ✅ VotingRegressor_metrics
#
# ================================================================================
# ✅ 총 25개 모델 결과 로드 완료
# 📊 컬럼: ['model_name', 'file_name', 'R2', 'RMSE', 'MAE', 'RMSLE', 'original_model_name', '학습시간']
# ⚠️  메트릭 없는 파일: 39개
# ================================================================================
#
# ================================================================================
# 📊 데이터 품질 체크 (회귀)
# ================================================================================
#
# [R2]
#   - 총 개수: 25
#   - NaN 개수: 0
#   - Inf 개수: 0
#   - 최소값: 0.135800
#   - 최대값: 0.992282
#   - 평균값: 0.620415
#   - 중앙값: 0.490944
#   - 표준편차: 0.323631
#
# [RMSE]
#   - 총 개수: 25
#   - NaN 개수: 0
#   - Inf 개수: 0
#   - 최소값: 3.396744
#   - 최대값: 35.877000
#   - 평균값: 19.702005
#   - 중앙값: 26.955540
#   - 표준편차: 13.565560
#
# [MAE]
#   - 총 개수: 25
#   - NaN 개수: 0
#   - Inf 개수: 0
#   - 최소값: 0.169450
#   - 최대값: 13.265600
#   - 평균값: 6.783882
#   - 중앙값: 9.888400
#   - 표준편차: 5.564691
#
# [RMSLE]
#   - 총 개수: 25
#   - NaN 개수: 13
#   - Inf 개수: 0
#   - 최소값: 0.012323
#   - 최대값: 0.460500
#   - 평균값: 0.087136
#   - 중앙값: 0.012882
#   - 표준편차: 0.170337
#   ⚠️  NaN 값이 있는 모델:
#       - AutoGluon_FastText_metrics
#       - blended_R2_20251205_170940_metrics
#       - blended_R2_20251205_170940_metrics
#       - blended_R2_latest_metrics
#       - blended_R2_latest_metrics
#   ⚠️  이상치 가능성 있는 모델 (3개):
#       - mercari_best_bert_metrics: 0.013892
#       - LGBMRegressor_reg_result: 0.442716
#       - VotingRegressor_metrics: 0.460500
#
# ================================================================================
# 🏆 상위 10개 모델
# ================================================================================
#                    model_name    RMSLE     RMSE      MAE       R2
#          mercari_best_metrics 0.012323 3.396744 0.169450 0.992282
#    mercari_best_glove_metrics 0.012323 3.396744 0.169450 0.992282
#    mercari_best_tfidf_metrics 0.012429 3.399601 0.172664 0.992269
# mercari_best_fasttext_metrics 0.012763 3.426364 0.176448 0.992146
# RandomForestRegressor_metrics 0.012763 3.426400 0.176400 0.992100
# RandomForestRegressor_metrics 0.012878 3.523800 0.179700 0.991700
# mercari_best_metrics_word2vec 0.012886 3.595831 0.181575 0.991350
# mercari_best_word2vec_metrics 0.012886 3.595831 0.181575 0.991350
#     mercari_best_bert_metrics 0.013892 3.780216 0.200824 0.990440
#     mercari_best_bert_metrics 0.027277 5.398647 0.700472 0.980503
#
# 📊 시각화 생성 중...
# ✅ 한글 폰트 설정 완료: Windows
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:396: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) Arial.
#   plt.tight_layout()
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:396: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from font(s) Arial.
#   plt.tight_layout()
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:396: UserWarning: Glyph 45230 (\N{HANGUL SYLLABLE NAJ}) missing from font(s) Arial.
#   plt.tight_layout()
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:396: UserWarning: Glyph 51012 (\N{HANGUL SYLLABLE EUL}) missing from font(s) Arial.
#   plt.tight_layout()
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:396: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) Arial.
#   plt.tight_layout()
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:396: UserWarning: Glyph 47197 (\N{HANGUL SYLLABLE ROG}) missing from font(s) Arial.
#   plt.tight_layout()
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:396: UserWarning: Glyph 51339 (\N{HANGUL SYLLABLE JOH}) missing from font(s) Arial.
#   plt.tight_layout()
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:396: UserWarning: Glyph 51020 (\N{HANGUL SYLLABLE EUM}) missing from font(s) Arial.
#   plt.tight_layout()
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:396: UserWarning: Glyph 45458 (\N{HANGUL SYLLABLE NOP}) missing from font(s) Arial.
#   plt.tight_layout()
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:396: UserWarning: Glyph 47784 (\N{HANGUL SYLLABLE MO}) missing from font(s) Arial.
#   plt.tight_layout()
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:396: UserWarning: Glyph 45944 (\N{HANGUL SYLLABLE DEL}) missing from font(s) Arial.
#   plt.tight_layout()
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:396: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from font(s) Arial.
#   plt.tight_layout()
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:396: UserWarning: Glyph 45733 (\N{HANGUL SYLLABLE NEUNG}) missing from font(s) Arial.
#   plt.tight_layout()
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:399: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) Arial.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:399: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from font(s) Arial.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:399: UserWarning: Glyph 45230 (\N{HANGUL SYLLABLE NAJ}) missing from font(s) Arial.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:399: UserWarning: Glyph 51012 (\N{HANGUL SYLLABLE EUL}) missing from font(s) Arial.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:399: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) Arial.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:399: UserWarning: Glyph 47197 (\N{HANGUL SYLLABLE ROG}) missing from font(s) Arial.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:399: UserWarning: Glyph 51339 (\N{HANGUL SYLLABLE JOH}) missing from font(s) Arial.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:399: UserWarning: Glyph 51020 (\N{HANGUL SYLLABLE EUM}) missing from font(s) Arial.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:399: UserWarning: Glyph 45458 (\N{HANGUL SYLLABLE NOP}) missing from font(s) Arial.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:399: UserWarning: Glyph 47784 (\N{HANGUL SYLLABLE MO}) missing from font(s) Arial.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:399: UserWarning: Glyph 45944 (\N{HANGUL SYLLABLE DEL}) missing from font(s) Arial.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:399: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from font(s) Arial.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# c:\big20\git\big20-ML-project2-team3\MercariPriceSuggestion\utils\results_report.py:399: UserWarning: Glyph 45733 (\N{HANGUL SYLLABLE NEUNG}) missing from font(s) Arial.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight')
# 💾 그래프 저장: ../images/quick_comparison.png
# c:\ProgramData\anaconda3\envs\mercari\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\mercari\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\mercari\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 45230 (\N{HANGUL SYLLABLE NAJ}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\mercari\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51012 (\N{HANGUL SYLLABLE EUL}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\mercari\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\mercari\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47197 (\N{HANGUL SYLLABLE ROG}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\mercari\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51339 (\N{HANGUL SYLLABLE JOH}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\mercari\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51020 (\N{HANGUL SYLLABLE EUM}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\mercari\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 45458 (\N{HANGUL SYLLABLE NOP}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\mercari\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47784 (\N{HANGUL SYLLABLE MO}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\mercari\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 45944 (\N{HANGUL SYLLABLE DEL}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\mercari\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\anaconda3\envs\mercari\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 45733 (\N{HANGUL SYLLABLE NEUNG}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# ✅ 한글 폰트 설정 완료: Windows
# 💾 RMSLE 순위 저장: ../images/quick_rmsle_ranking.png
#
# 💾 CSV 저장: ../results/quick_report.csv
#                             model_name  \
# 0                 mercari_best_metrics
# 1           mercari_best_glove_metrics
# 2           mercari_best_tfidf_metrics
# 3        mercari_best_fasttext_metrics
# 4        RandomForestRegressor_metrics
# 5        RandomForestRegressor_metrics
# 6        mercari_best_metrics_word2vec
# 7        mercari_best_word2vec_metrics
# 8            mercari_best_bert_metrics
# 9            mercari_best_bert_metrics
# 10            LGBMRegressor_reg_result
# 11             VotingRegressor_metrics
# 12          AutoGluon_FastText_metrics
# 13  blended_R2_20251205_170940_metrics
# 14  blended_R2_20251205_170940_metrics
# 15           blended_R2_latest_metrics
# 16           blended_R2_latest_metrics
# 17           CatBoostRegressor_metrics
# 18        manual_ensemble_top3_metrics
# 19            PyCaret_FastText_metrics
# 20                       Ridge_metrics
# 21                       Ridge_metrics
# 22                       Ridge_metrics
# 23                       Ridge_metrics
# 24             VotingRegressor_metrics
#
#                                             file_name        R2       RMSE  \
# 0           mercari_best_metrics_20251206_172008.json  0.992282   3.396744
# 1     mercari_best_glove_metrics_20251209_114031.json  0.992282   3.396744
# 2     mercari_best_tfidf_metrics_20251206_171930.json  0.992269   3.399601
# 3   mercari_best_fasttext_metrics_20251207_170940....  0.992146   3.426364
# 4   RandomForestRegressor_metrics_20251206_180549....  0.992100   3.426400
# 5   RandomForestRegressor_metrics_20251206_182703....  0.991700   3.523800
# 6   mercari_best_metrics_word2vec_20251206_175136....  0.991350   3.595831
# 7   mercari_best_word2vec_metrics_20251208_103455....  0.991350   3.595831
# 8      mercari_best_bert_metrics_20251206_203920.json  0.990440   3.780216
# 9      mercari_best_bert_metrics_20251206_150433.json  0.980503   5.398647
# 10      LGBMRegressor_reg_result_20251210_103632.json  0.490944  26.955540
# 11       VotingRegressor_metrics_20251206_135857.json  0.400000  29.953200
# 12    AutoGluon_FastText_metrics_20251205_134652.json  0.603100  24.361700
# 13  blended_R2_20251205_170940_metrics_20251205_17...  0.409500  29.713600
# 14  blended_R2_20251205_170940_metrics_20251205_17...  0.409500  29.713600
# 15     blended_R2_latest_metrics_20251205_172326.json  0.409500  29.713600
# 16     blended_R2_latest_metrics_20251205_172942.json  0.409500  29.713600
# 17     CatBoostRegressor_metrics_20251206_102211.json  0.406200  29.797200
# 18  manual_ensemble_top3_metrics_20251204_181317.json  0.135800  35.877000
# 19      PyCaret_FastText_metrics_20251205_171001.json  0.409500  29.713600
# 20                 Ridge_metrics_20251204_145930.json  0.239700  33.649300
# 21                 Ridge_metrics_20251204_155728.json  0.254600  33.317900
# 22                 Ridge_metrics_20251204_171808.json  0.239700  33.649300
# 23                 Ridge_metrics_20251204_180758.json  0.239700  33.649300
# 24       VotingRegressor_metrics_20251204_171458.json  0.546700  25.831500
#
#           MAE     RMSLE original_model_name         학습시간
# 0    0.169450  0.012323                 NaN          NaN
# 1    0.169450  0.012323                 NaN          NaN
# 2    0.172664  0.012429                 NaN          NaN
# 3    0.176448  0.012763                 NaN          NaN
# 4    0.176400  0.012763                 NaN          NaN
# 5    0.179700  0.012878                 NaN          NaN
# 6    0.181575  0.012886                 NaN          NaN
# 7    0.181575  0.012886                 NaN          NaN
# 8    0.200824  0.013892                 NaN          NaN
# 9    0.700472  0.027277                 NaN          NaN
# 10   9.888400  0.442716       LGBMRegressor  1514.396034
# 11  10.604400  0.460500                 NaN          NaN
# 12   8.823900       NaN                 NaN          NaN
# 13  10.847400       NaN                 NaN          NaN
# 14  10.847400       NaN                 NaN          NaN
# 15  10.847400       NaN                 NaN          NaN
# 16  10.847400       NaN                 NaN          NaN
# 17  11.001300       NaN                 NaN          NaN
# 18  13.265600       NaN                 NaN          NaN
# 19  10.847400       NaN                 NaN          NaN
# 20  12.703100       NaN                 NaN          NaN
# 21  12.589200       NaN                 NaN          NaN
# 22  12.703100       NaN                 NaN          NaN
# 23  12.703100       NaN                 NaN          NaN
# 24   8.769400       NaN                 NaN          NaN
