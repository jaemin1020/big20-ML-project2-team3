# %%
# 타 vectorizer 추가 
# 사용전  pycaret_evn에 
# pip install gensim 
# pip install sentence-transformers

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 10
#       8 import warnings
#       9 import re
# ---> 10 from gensim.models import FastText
#      11 from sentence_transformers import SentenceTransformer
#      13 warnings.filterwarnings("ignore")
#
# ModuleNotFoundError: No module named 'gensim'

# %%
# TF-IDF baseline
analyzer_tfidf = MercariPyCaretAnalyzer7()
analyzer_tfidf.load_data()
analyzer_tfidf.vectorize_text_tfidf()
analyzer_tfidf.setup_pycaret()
analyzer_tfidf.find_and_blend_models()
analyzer_tfidf.save_metrics()

# FastText
analyzer_fasttext = MercariPyCaretAnalyzer7()
analyzer_fasttext.load_data()
analyzer_fasttext.vectorize_text_fasttext()
analyzer_fasttext.setup_pycaret()
analyzer_fasttext.find_and_blend_models()
analyzer_fasttext.save_metrics()

# BERT
analyzer_bert = MercariPyCaretAnalyzer7()
analyzer_bert.load_data()
analyzer_bert.vectorize_text_bert()
analyzer_bert.setup_pycaret()
analyzer_bert.find_and_blend_models()
analyzer_bert.save_metrics()
