# %%
import os
import sys
import glob

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from pycaret.clustering import setup, create_model, assign_model, models, pull
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from datetime import datetime
import warnings
import time

from utils import preprocessing
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\tj\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
warnings.filterwarnings('ignore')
DATA_PATH = '../data'
OUTPUT_DIR = '../results'
IMAGE_DIR = '../images'
    
document_df = preprocessing.get_default_data()
# Out:
# 📂 51개 파일 발견
# 🔄 텍스트 전처리 시작...
#    옵션: HTML제거=True, URL제거=True, 숫자제거=True
#    옵션: 불용어제거=True, Lemmatization=True, Stemming=False
# ✅ 전처리 완료:
#    - 원본 문서 수: 51
#    - 제거된 빈 문서: 0
#    - 최종 문서 수: 51
#    - 평균 단어 수: 1266.9

# %%
# 최적 k 선택 + 대표 문서 추출 + PCA/t-SNE 시각화 함수

from sklearn.decomposition import TruncatedSVD, PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.manifold import TSNE

def auto_cluster_pipeline(document_df, text_column='processed_text',
                          max_features=5000, svd_dim=50, k_range=(2,10), top_n=5,
                          visualize_method='pca'):
    """
    document_df만 넣으면 자동으로:
    1. TF-IDF 벡터화
    2. SVD 차원 축소
    3. KMeans 여러 k 평가
    4. 최적 k 선택
    5. 클러스터별 대표 문서 추출 (평균 벡터와 가장 가까운 문서)
    6. PCA/t-SNE 시각화에서 대표 문서 강조 표시
    
    Parameters:
        document_df (pd.DataFrame): 텍스트 데이터프레임
        text_column (str): 텍스트 컬럼명
        max_features (int): TF-IDF 최대 특성 수
        svd_dim (int): SVD 차원 축소 크기
        k_range (tuple): KMeans k 탐색 범위
        top_n (int): 클러스터별 유사 문서 Top-N
        visualize_method (str): 'pca' 또는 'tsne'
    
    Returns:
        dict: 평가 지표, 최적 k, 대표 문서 및 유사 문서
    """
    # 1. TF-IDF 벡터화
    texts = document_df[text_column]
    vectorizer = TfidfVectorizer(max_features=max_features, stop_words='english')
    X = vectorizer.fit_transform(texts)

    # 2. 차원 축소 (SVD)
    svd = TruncatedSVD(n_components=svd_dim, random_state=42)
    X_reduced = svd.fit_transform(X)

    # 3. 여러 k 값 평가
    scores = {}
    for k in range(k_range[0], k_range[1] + 1):
        kmeans = KMeans(n_clusters=k, random_state=42)
        labels = kmeans.fit_predict(X_reduced)
        
        if len(set(labels)) > 1:
            sil = silhouette_score(X_reduced, labels)
            db = davies_bouldin_score(X_reduced, labels)
            ch = calinski_harabasz_score(X_reduced, labels)
            scores[k] = {"silhouette": sil, "davies_bouldin": db, "calinski": ch}
        else:
            scores[k] = {"silhouette": None, "davies_bouldin": None, "calinski": None}

    # 4. 최적 k 선택 (세 지표 종합)
    sil_values = [v["silhouette"] for v in scores.values() if v["silhouette"] is not None]
    db_values  = [v["davies_bouldin"] for v in scores.values() if v["davies_bouldin"] is not None]
    ch_values  = [v["calinski"] for v in scores.values() if v["calinski"] is not None]

    def normalize(values, higher_is_better=True):
        arr = np.array(values)
        if higher_is_better:
            return (arr - arr.min()) / (arr.max() - arr.min())
        else:
            return (arr.max() - arr) / (arr.max() - arr.min())

    sil_norm = normalize(sil_values, True)
    db_norm  = normalize(db_values, False)
    ch_norm  = normalize(ch_values, True)

    combined_scores = sil_norm + db_norm + ch_norm
    valid_keys = [k for k,v in scores.items() if v["silhouette"] is not None]
    best_index = np.argmax(combined_scores)
    best_k = valid_keys[best_index]

    # 5. 최적 k로 KMeans 실행
    final_kmeans = KMeans(n_clusters=best_k, random_state=42)
    labels = final_kmeans.fit_predict(X_reduced)
    document_df['Cluster'] = labels

    # 6. 대표 문서 추출 (평균 벡터와 가장 가까운 문서)
    similarity_matrix = cosine_similarity(X)
    representatives = {}
    for cluster_id in range(best_k):
        cluster_docs = document_df[document_df['Cluster'] == cluster_id]
        if cluster_docs.empty:
            continue
        cluster_indices = cluster_docs.index
        cluster_vectors = X[cluster_indices].toarray()
        cluster_center = cluster_vectors.mean(axis=0)
        sims_to_center = cosine_similarity([cluster_center], cluster_vectors)[0]
        rep_idx_local = np.argmax(sims_to_center)
        rep_idx = cluster_indices[rep_idx_local]
        rep_text = document_df.loc[rep_idx, text_column]
        sim_scores = similarity_matrix[rep_idx]
        top_indices = np.argsort(sim_scores)[-top_n-1:-1]
        similar_docs = document_df.iloc[top_indices][[text_column, 'Cluster']]
        representatives[cluster_id] = {
            "representative": rep_text,
            "similar_docs": similar_docs
        }

    # 7. 시각화 (PCA/t-SNE)
    if visualize_method == 'pca':
        reducer = PCA(n_components=2, random_state=42)
        coords = reducer.fit_transform(X_reduced)
    elif visualize_method == 'tsne':
        reducer = TSNE(n_components=2, random_state=42, perplexity=30)
        coords = reducer.fit_transform(X_reduced)
    else:
        raise ValueError("visualize_method는 'pca' 또는 'tsne'만 가능합니다.")

    plt.figure(figsize=(10,8))
    plt.scatter(coords[:,0], coords[:,1], c=labels, cmap='tab10', alpha=0.6)
    for cluster_id, info in representatives.items():
        rep_text = info['representative']
        rep_idx = document_df[document_df[text_column] == rep_text].index[0]
        plt.scatter(coords[rep_idx,0], coords[rep_idx,1],
                    marker='*', s=250, color='black', edgecolor='white',
                    label=f"Cluster {cluster_id} 대표")
    plt.title(f"문서 군집화 시각화 ({visualize_method.upper()})")
    plt.xlabel("Component 1")
    plt.ylabel("Component 2")
    plt.legend()
    plt.grid(True)
    plt.show()

    return {
        "scores": scores,
        "best_k": best_k,
        "best_metrics": scores[best_k],
        "combined_score": combined_scores[best_index],
        "representatives": representatives
    }

# %%
# 맑은 고딕 폰트 설정
plt.rc('font', family='Malgun Gothic')

result = auto_cluster_pipeline(document_df, text_column='processed_text', top_n=5, visualize_method='pca')

print("=== 최적 k 선택 결과 ===")
print(f"Best k = {result['best_k']}")
print(f"Silhouette = {result['best_metrics']['silhouette']:.3f}")
print(f"Davies-Bouldin = {result['best_metrics']['davies_bouldin']:.3f}")
print(f"Calinski-Harabasz = {result['best_metrics']['calinski']:.3f}")
print(f"Combined Score = {result['combined_score']:.3f}")

print("\n=== 클러스터별 대표 문서 및 유사 문서 ===")
for cluster_id, info in result['representatives'].items():
    print(f"\nCluster {cluster_id}:")
    print("대표 문서:", info['representative'])
    print("유사 문서 Top-N:")
    print(info['similar_docs'])
    
    
reuslt_mark = '''
- 이제 document_df만 넣으면 최적 k 선택 + 대표 문서 추출 + PCA/t-SNE 시각화까지 자동으로 실행
- 대표 문서는 클러스터 평균 벡터와 가장 가까운 문서로 선택
- 시각화에서는 대표 문서가 ⭐ 마커로 강조되어 표시
'''
# Out:
# === 최적 k 선택 결과 ===
# Best k = 10
# Silhouette = 0.152
# Davies-Bouldin = 1.789
# Calinski-Harabasz = 2.764
# Combined Score = 2.000
#
# === 클러스터별 대표 문서 및 유사 문서 ===
#
# Cluster 0:
# 대표 문서: thing like point must push micro sized right angle end ac adapter snap place battery may charge full size right shift key enough drop understand full featured laptop squeezed smaller manageable size keyboard size found standard computer machine run little hot keyboard responsive feel larger key along oversize right shift key real plus yes airplane trip last couple day thankful small size person front reclined seat back way whole flight taking machine airport security much easier full size notebook even battery life continues hold keyboard true godsend full size key recommend minimizing size scroll zone right bottom wise find screen suddenly scrolling want huge improvement old full size laptop many way thing less ideal big deal tiny light slightly smaller standard keyboard problem use touch typist key good size feel good keyboard terrific solid feel full size perfect size weight take almost anywhere machine comfortable small keyboard ever used key flat surface fingerpads touch actually size standard keyboard give functionality full sized laptop small screen may take getting used regular laptop give kind battery life function absent used people time anyway tradeoff fewer feature greatly increased battery life take latter smaller size video play even smoother keyboard actually pleasure use inspite small size size one smaller yet still maintaining reasonable useability ended one based smaller size lighter weight overwhelming number positive review pro wanted love small size long battery life brilliant blue color light weight performance great size remember designed speed demon highly portable cordless extended period time must remind buyer meant replacement full size pc cd dvd drive although get external small easy grab go business place open full size laptop easy take note keep copy working main pc continue working ever keyboard quite full sized course easy get used real problem trying use toshiba satellite flying past year distance top display edge netbook open practical size get work done flight keyboard standard size large enough know use screen size seems cramped everything needed laptop without heavy bulky size overall size seems right target small enough easily travel large enough usable full sized laptop freaking bulky heavy battery wouldnt even make though one evening class surprisingly readable screen size speaking keyboard relatively large size size normal one writing longer text problem complaint small compressed size arrow suppose probably unavoidable someone else suggested going store first check size inch bit small make sure check inch model best buy office max make sure ok size run quietly operates window efficiently staying incredibly cool compared instant burn lap sauna full sized hp pavillion speaking typing keyboard great almost full size screen nice adequately sized use fullscreen browsing xp great glacial vista laptop despite atom much faster full size vista laptop screen size work fine size regular keyboard somewhat larger average male hand adapted completely week reviewer complained physical size battery extrusion bottom netbook great battery life decent sized screen keyboard large enough comfortable type originally bought eee take whenever laptop big take somewhere started exclusively using eee place laptop portability battery life greatly exceeds full size laptop light weight small size highly important travel asus comfortable keyboard normal sized make adjustment typing needed business trip full size laptop need service netbook great love small compact size ultra portability advice visit store personally try keyboard screen size although screen relatively small eye really hard get used size screen clear bright prob reading article writing essay one thing found difficult get used size screen also tried full size logitech trackman little wired logitech notebook mouse suck like mouse usable mouse idea good time using xion fan pad fold size closed netbook run usb port screen sharp readable even tiny t ...
# 유사 문서 Top-N:
#                                        processed_text  Cluster
# 34  easy read touching screen work great zoom butt...        7
# 4   ghz fsb cpu glossy display cell wh li ion batt...        8
# 35  always video screen sharp bright inch screen g...        7
# 36  keep mind get room full light step outdoors sc...        7
# 19  think new keyboard rival great hp mini keyboar...        0
#
# Cluster 1:
find occasional mispronunciation entertaining issue know near public road give direction road spoken turn turn direction clear timely real gripe software interface side would inability show way street overhead map particular model support garmin routing feature sync pc expensive model pick multiple waypoints instead point point direction system even get turn turn direction program google map feature work garmin unit time facing closed roadway terribly stuck highway traffic get slick change direction destination given literally less second ask button gave u direction right carmel purpose gps give direction unfamiliar location voice direction great sometimes mispronounces name take little get satellite sometimes set soon get car time road actually need direction going great time torturing poor thing deliberately following direction driving one day downtown sacramento wt gave bad direction one place sacramento avoided complex one read fm update confuse device changing direction obstruction cleared good option like able select different voice however using daniel english accent seems clearing throat end direction load quickly pretty accurate direction recalculate quickly miss turn often get phone call talking someone would nice ability quickly make voice direct ...
# 유사 문서 Top-N:
#                                        processed_text  Cluster
# 9   quot widescreen display bonus made smoother gr...        7
# 48  another thing consider paid less came fm trans...        3
# 34  easy read touching screen work great zoom butt...        7
# 50  voice prompt map wonderful especially driving ...        7
# 0   accurate part find garmin software provides ac...        3
#
# Cluster 4:
# 대표 문서: fact entire navigation structure completely revised still getting used huge step forward navigation huge improvement clearly amazon hard work make navigation quicker easier tried free day trial newspaper downloads great way get news advertising distraction easy navigate automatically downloaded every day got used navigation easy sony store cumbersome navigate slow despite lighter text prefer thinness improved navigation use far kindle wireless delivery easy navigation ad need flip page find place left main issue kindle navigation button design placement easy navigate without risk accidentally changing page home page easier navigate let quickly navigate periodical moving next article click right left section article list flick losing side cursor give kindle cleaner look greatly improved navigation real benefit ease navigation one compelling new feature kindle problem kindle expect reader amazon asking book publisher adhere standard navigation support feature amazon manpower review book submitted see published specification amazon claim faster feel almost twice fast menu much better organized easier navigate picture crisp clear quick learning curve navigate page article section control well placed procedure navigation easy learn easy read navigate etc way navigator easily worth mentioning make navigating much easier navigation stick work much better expected star significant improvement ergonomics navigation february several screen navigation improvement due faster ink kindle roller button quirky silver navigation bar gone new way navigation toggle left right plus press generally enjoying navigation change significantly easier hold navigate relative kindle beautiful little product feel sleek sturdy booklike hand control finally ought navigation interface intuitive easy learn advertised easy eye combined font sizing easy navigation meant pdfs table content work navigable set link typing navigating ink technology take patience little getting used especially frenetic folk task mode ink take moment display screen input keyboard navigation contoller keyboard input stiff requires direct punch tiny key register keyboard close bottom unit kindle flexible typing something laborious even tortured action relatively short note paragraph actually written kindle navigation much easier way button occassional minor ghosting problem screen completely update page turn navigating realize either sure would easier touch place want navigate use joystick instead display book title way navigate last page read fastest way navigate larger work would leave page go table content choose likely chapter proceed page page till reach desired page mentioned free copy also active table content navigation well near impossible beyond simply ploughing form start finish navigation using next previous page button think area kindle met expectation sluggish cursor poor navigation almost non existent capability organize content major drawback largest difference touch screen bottom primary thing reader becomes non issue navigation actually slightly awkward navigate using touch screen look screen whereas kindle use directional rocker planned direction kindle really fun use blast learning navigate use feature find navigating device page turn menu etc also found using navigation button difficult learn searching navigating old geezer like anybody far better navigation article periodical easier navigation overall five way controller replacing clumsy time consuming navigation wheel cursor new navigation button work well keyboard feel good finger thumb stick navigation kindle take getting used especially use touch screen mouse everyday easy page turn navigation navigating menu almost intuitive becomes easier easier go button work well even large finger navigating position control easily mastered easy use effectively find easier hand navigating screen version page easy flip menu easy navigate easy forget reading real book screen read like paper easy navigate find reading f ...
# 대표 문서: happy accord performance quite adequate nice look great long distance cruiser eco engine poor performance gas mileage highway overall performance good comfort level poor impressed performance well efficiency gain room performance good mpg size excellent reliability record test drove lexus bmw series infiniti enjoyed honda performance equally far less money happy car enjoy ride performance performance engine smooth car rattle mile horrible performance even four cylinder great performance handling make real winner engine performance lack punch head rest poor design lack driver seat memory rear seat radio system marginal compared bose seat hard small large person seem many component enter vcm performance vary widely car car feature quality reliability performance price car maker touch hp engine good compromise performance fuel economy owned car week pleasantly surprised performance build quality car lack performance handling previous year good looking inside comfortable roomy commendable performance excellent gas mileage still enjoy interior exterior styling well overall performance handling put highway weekend performance amazing bigger size taken getting used additional horsepower compared performance like night day fit right fun drive great stereo fuel economy performance want sport sedan handling performance pay much buy true sport sedan went comfort performance fit budget ex cyl engine researched many make model performance quality style accord hand car performance outstanding like sport car coupe lot power spd car great balance style performance reliability problem quality performance etc engine performance lacking anywhere close series many facet namely performance sadly say others surpasses cylinder lack performance handling gas saving minimal car great styling performance purchased leather think honda could better design performance love styling performance handling looking luxury feel car great performance good price overweight pound lot road noise combined performance vcm grade logic automatic transmission mke miserable driver interior design performance highlight looking mid size coupe style performance season traction capability styling fantastic performance one would hope diminish performance car annoying tracking almost month research american japanese mid size car model two stand performance reliability safety honda accord toyota camry never experienced smooth performance stability pick mileage comfort enjoying new honda accord admire engine performance comfort driving atleast mile day job owned honda come rely fantastic quality performance lack maintenance issue car superb performance styling quality engineering fit finish whole banana performance incredible gas mileage great vehicle type performance could happier performance ride car first tested ex performance handling car sold get honda outdone styling performance ride comfort overall performance absolute joy previous model boring aestically performance wise
# 유사 문서 Top-N:
#                                        processed_text  Cluster
# 22  quiet get good gas mileage look clean inside m...        5
# 16  ride seems comfortable gas mileage fairly good...        5
# 7   ride seems comfortable gas mileage fairly good...        2
# 6   driver seat comfortable car compared model sim...        2
# 26  eee super hybrid engine utility let user overc...        6
#
# Cluster 7:
# 대표 문서: easy read touching screen work great zoom button side screen make bit easier zoom button opposite side screen screen easily readable sun love automatically dims night display excellent layout information screen good showing upcoming turn top speed local speed limit estimated time arrival bottom text speech great look screen endangering others road voice update garmin put scratchiness robotic sounding voice became crisp audible widescreen plus highly recommend even though wide screen stick back pocket conveniently used walking direction screen bright easy see direct sunlight night time looking simple wide screen gps nuvi right choice one favorite feature garmin odometer screen allow track sort data long car trip tell main screen estimated time arrival change depending upon stop speed additionally find data odometer screen fasscinating another screen touch button show turn turn direction coming plan even better especially area enough familiarity considered dangerous arrow top screen show direction next turn make thing worse main st may screen default scale way map displayed good wide screen help see map area magellan screen inch smaller really noticeable magellan text voice often would take much longer route even though told take freeway noticeable thing screen much easier read text voice extremely valuable much better beep need turn hand week using garmin seems understand poi far mile away show screen touched screen easy see voice tell accurate switched nuvi screen nuvi got cracked screen size better screen touch sensitivity responsive old plus better looking screen home screen show four option time viewing map zoom tapping appropriate icon located top right screen noticed see speed limit sign road indicating change speed limit road nuvi far behind changing speed limit screen missed spoken direction look top screen written direction although nuvi verbalize direction look screen see exit need take screen bright map generally good love touch screen technology time drove overpass interstate intersection shown screen typical garmin product work well wide screen nice functionally slight problem unit press pretty hard screen want drag map extra feature lesser model find highly beneficial include spoken street name wide screen display screen get say system software missing use suction cup mount like keep screen frame vision without turning head make s