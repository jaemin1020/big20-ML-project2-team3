# %%
import pandas as pd
import glob, os
import warnings 
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 700)

# %%
path = r'../data' # r'C:\big20\ml_dev\chap08\topics' r 쓴이유는 안에 // 가 ecape문자가 되기 때문이다!!
# path로 지정한 디렉터리 밑에 있는 모든 .data 파일들의 파일명을 리스트로 취합
all_files = glob.glob(os.path.join(path, "*.data"))    # 많이 나올 수 있다!!!
all_files # 파일명이 레이블이다! 제품명들어 있음
# Out:
# ['./topics\\accuracy_garmin_nuvi_255W_gps.txt.data',
#  './topics\\bathroom_bestwestern_hotel_sfo.txt.data',
#  './topics\\battery-life_amazon_kindle.txt.data',
#  './topics\\battery-life_ipod_nano_8gb.txt.data',
#  './topics\\battery-life_netbook_1005ha.txt.data',
#  './topics\\buttons_amazon_kindle.txt.data',
#  './topics\\comfort_honda_accord_2008.txt.data',
#  './topics\\comfort_toyota_camry_2007.txt.data',
#  './topics\\directions_garmin_nuvi_255W_gps.txt.data',
#  './topics\\display_garmin_nuvi_255W_gps.txt.data',
#  './topics\\eyesight-issues_amazon_kindle.txt.data',
#  './topics\\features_windows7.txt.data',
#  './topics\\fonts_amazon_kindle.txt.data',
#  './topics\\food_holiday_inn_london.txt.data',
#  './topics\\food_swissotel_chicago.txt.data',
#  './topics\\free_bestwestern_hotel_sfo.txt.data',
#  './topics\\gas_mileage_toyota_camry_2007.txt.data',
#  './topics\\interior_honda_accord_2008.txt.data',
#  './topics\\interior_toyota_camry_2007.txt.data',
# ...

# %%
# 파일명과 리뷰 꺼내서 저장, 텍스트, 이미지 파일 처리할때 유용할끄야!!! 기억해~~~ 
filename_list = [] # 파일명 저장
opinion_text  = [] # 리뷰를 저장하는 리스트 

for file_ in all_files:
    # 개별 파일을 읽어서 DataFrame으로 생성 
    df = pd.read_table(file_, index_col=None, header=0, encoding='latin1') # english인 경우 latin1 
    
    # 파일명 추축 (레이블이니까)
    # filename_ = file_.split('\\')[-1] # window용, Mac = '/' # './topics\\voice_garmin_nuvi_255W_gps.txt.data' => voice_garmin_nuvi_255W_gps.txt.data 만 추출
    # filename = filename_.split('.')[0] # voice_garmin_nuvi_255W_gps.txt.data 에서 voice_garmin_nuvi_255W_gps
    filename = file_.split('\\')[-1].split('.')[0]

    filename_list.append(filename)
    opinion_text.append(df.to_string()) # 모든 내용을 컬럼명 포함 모두 문자로 만들어줌

# 파일명 리스트와 파일 내용 리스트를  DataFrame으로 생성
document_df = pd.DataFrame({
    'filename':     filename_list, # label이 됨
    'opinion_text': opinion_text
})
document_df.head()
# Out:
#                          filename  \
# 0   accuracy_garmin_nuvi_255W_gps
# 1  bathroom_bestwestern_hotel_sfo
# 2      battery-life_amazon_kindle
# 3      battery-life_ipod_nano_8gb
# 4     battery-life_netbook_1005ha
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   opinion_text
# ...

# %%
# data_list = []

# for file_ in all_files:
#     # 1. 파일 경로에서 파일명(레이블) 추출
#     # os.path.basename을 사용해 OS 호환성 확보
#     filename = os.path.basename(file_).split('.')[0] 

#     # 2. 파이썬 기본 open() 함수로 파일 내용 전체를 읽기
#     # encoding='latin1' 유지
#     try:
#         with open(file_, 'r', encoding='latin1') as f:
#             text_content = f.read() # 파일 내용 전체를 하나의 문자열로 저장
            
#         # 3. 딕셔너리 형태로 리스트에 추가
#         data_list.append({
#             'filename': filename,
#             'opinion_text': text_content
#         })
        
#     except FileNotFoundError:
#         print(f"Error: {file_} not found.")
#     except Exception as e:
#         print(f"An error occurred reading {file_}: {e}")

# # 반복문 종료 후 한 번에 DataFrame 생성
# document_df = pd.DataFrame(data_list)

# print(document_df.head())
# print(document_df['opinion_text'][0][:200]) # 처음 200자 출력 예시

# %%
# # 확인용 코드
# df = pd.read_table(all_files[0], index_col=None, header=0, encoding='latin1') # english인 경우 latin1 
# # df.head()
# df.to_string()
# Out:
# "                                                                                                                                                                                                                                                               , and is very, very accurate .\n0                                                                                                                                                                           but for the most part, we find that the Garmin software provides accurate directions, whereever we intend to go .\n1                                                                                                              This function is not accurate if you don't leave it in battery mode say, when you stop at the Cracker Barrell for lunch and to play one of those trangle games with the tees .\n2                                                                                                                                       
# ...

# %% [markdown]
# 문서를 TF-IDF 형태로 피처 벡터화하겠습니다. TfidfVectorizer는 Lemmatization(어근 추출) 같은 어근 변환을 직접 지원하진 않지만,
# **tokenizer(단어분리)** 인자에 커스텀 어근 변환 함수를 적용해 어근 변환을 수행할 수 있습니다.
# 이를 위해 LemNormalize() 함수를 만들겠습니다(해당 함수는 이전에 설명드린 단어 토큰화, 스톱 워드 제거, 어근 변환에 기반하고 있기에 여기서 언급 드리지 않고, 부록으로 제공되는 소스
# 코드에서 보다 자세한 설명을 드리고 있으니, 참조 부탁드립니다).
# ngram은 (1,2)로 하고, min_df와 max_df 범위를 설정해 피처의 개수를 제한하겠습니다.
# TfidfVectorizer의 fit_transform()의 인자로 document_df DataFrame의 opinion_text 칼럼을 입력하면
# 개별 문서 텍스트에 대해 TF-IDF 변환된 피처 벡터화된 행렬을 구할 수 있습니다.

# %%
# 함수 만들기 : English 처리용
from nltk.stem import WordNetLemmatizer
import nltk
import string

# 제외할 문자 dict 생성
remove_punct_dict = dict((ord(punct), None) for punct in string.punctuation)
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~' ord(puct) => 숫자로 바꾼후 key:value 만든 후 
lemmar = WordNetLemmatizer()

# 입력으로 들어온 token단어들에 대해서 lemmatization 어근 변환.
def LemTokens(tokens):
    return [lemmar.lemmatize(token) for token in tokens]


# TfidfVectorizer 객체 생성 시 tokenizer인자로 해당 함수를 설정하여 lemmatization 적용
# 입력으로 문장을 받아서 stop words 제거-> 소문자 변환 -> 단어 토큰화 -> lemmatization 어근 변환.
def LemNormalize(text):
    # 한국어는 nltk 못씀!!!! 왜냐 지원 안혀~ , 글고 어근을 추출하자노.. 우리는 '형태소'인디 
    return LemTokens(nltk.word_tokenize(text.lower().translate(remove_punct_dict))) # word_tokenize(분리하겠다!)
  
# 영어 - 문서안에서 단어를 추출하고 (어근을 추출하고 그걸) 숫자로 변환 , 한그은 어근이 아닌 형태소!!! 이 코드는 한국어에 적용 불가

# %%
##  한국어 처리! 프로젝트에 써라! AIHUB 이용하라 ######################################
from konlpy.tag import Okt # konlpy 설치해야 함!!!!
import re

# Okt 객체 생성 (트위터 형태소 분석기)
okt = Okt()

# 1. 토큰화 및 어간(형태소) 추출 (Lemmatization 대응)
def KoTokens(text):
    # stem=True : 동사/형용사를 원형으로 변환 (예: '합니다' -> '하다', '예쁜' -> '예쁘다')
    # norm=True : 오타나 SNS 스타일 문체를 정제 (예: '안뇽' -> '안녕')
    return okt.morphs(text, stem=True, norm=True)

# 2. 전처리 및 토큰화 통합 함수 (LemNormalize 대응)
def KoNormalize(text):
    # 정규표현식을 이용한 특수문자 제거 (한글, 영문, 숫자, 공백만 남김)
    # string.punctuation을 쓰는 것보다 한글 텍스트 정제에 더 효과적입니다.
    text = re.sub(r'[^가-힣a-zA-Z0-9\s]', '', text)
    
    # 영어가 섞여 있을 경우를 위해 소문자 변환
    text = text.lower()
    
    # 형태소 분석 및 리스트 반환
    return KoTokens(text)

# --- 테스트 실행 ---
sample_text = "아버지가 방에 들어가신다! (Father enters the room.) 웃고 계십니다."
result = KoNormalize(sample_text)

print(f"원본: {sample_text}")
print(f"결과: {result}")

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# tokenizer에 위에서 정의한 KoNormalize 함수 지정
tfidf_vect = TfidfVectorizer(tokenizer=KoNormalize, min_df=1)

# 예시 데이터 학습
sentences = ['아버지가 방에 들어가신다.', '어머니는 부엌에서 요리하신다.']
tfidf_matrix = tfidf_vect.fit_transform(sentences)

print(tfidf_vect.get_feature_names_out())
# 출력 예시: ['가다', '나다', '방', '부엌', '아버지', '어머니', '에', '에서', '요리', '하다']
# (조사와 어간이 분리되고 기본형으로 바뀐 것을 확인할 수 있습니다)

# %%
import string
string.punctuation # '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~' 야들 전부 삭제할때 유용하지만 요즘은 지우면 안돼!!!
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# F-IDF 기반 Vectorization 적용 및 KMeans 군집화 수행
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vect = TfidfVectorizer(tokenizer=LemNormalize, stop_words='english' , \
                             ngram_range=(1,2), min_df=0.05, max_df=0.85 )

#opinion_text 컬럼값으로 feature vectorization 수행
feature_vect = tfidf_vect.fit_transform(document_df['opinion_text'])

# %%
# 군집화 하자! 센터를 찾을꺼다
from sklearn.cluster import KMeans

# 5개 집합으로 군집화 수행. 예제를 위해 동일한 클러스터링 결과 도출용 random_state=0 
km_cluster = KMeans(n_clusters=5, max_iter=10000, random_state=0)
km_cluster.fit(feature_vect)
cluster_label = km_cluster.labels_
cluster_centers = km_cluster.cluster_centers_

# %%
document_df['cluster_label'] = cluster_label
document_df.head()
## DBSCAN 돌리면 관련없는애들 좀 더 거를 수 있을 지도?
# Out:
#                          filename  \
# 0   accuracy_garmin_nuvi_255W_gps
# 1  bathroom_bestwestern_hotel_sfo
# 2      battery-life_amazon_kindle
# 3      battery-life_ipod_nano_8gb
# 4     battery-life_netbook_1005ha
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   opinion_text  \
# ...

# %%
document_df[document_df['cluster_label']==0].sort_values(by='filename') # 아마존킨들 관련
# Out:
#                          filename  \
# 5           buttons_amazon_kindle
# 10  eyesight-issues_amazon_kindle
# 12            fonts_amazon_kindle
# 23       navigation_amazon_kindle
# 27            price_amazon_kindle
# 28       price_holiday_inn_london
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    opinion_text  \
# ...

# %%
document_df[document_df['cluster_label']==1].sort_values(by='filename') # 호텔관련
# Out:
#                            filename  \
# 1    bathroom_bestwestern_hotel_sfo
# 13          food_holiday_inn_london
# 14           food_swissotel_chicago
# 15       free_bestwestern_hotel_sfo
# 20   location_bestwestern_hotel_sfo
# 21      location_holiday_inn_london
# 24    parking_bestwestern_hotel_sfo
# 32          room_holiday_inn_london
# 30      rooms_bestwestern_hotel_sfo
# 31          rooms_swissotel_chicago
# 38    service_bestwestern_hotel_sfo
# 39       service_holiday_inn_london
# 40  service_swissotel_hotel_chicago
# 45      staff_bestwestern_hotel_sfo
# 46          staff_swissotel_chicago
#
# ...

# %%
document_df[document_df['cluster_label']==2].sort_values(by='filename') # 전자제품?
# Out:
#                            filename  \
# 0     accuracy_garmin_nuvi_255W_gps
# 8   directions_garmin_nuvi_255W_gps
# 9      display_garmin_nuvi_255W_gps
# 19          keyboard_netbook_1005ha
# 33   satellite_garmin_nuvi_255W_gps
# 34      screen_garmin_nuvi_255W_gps
# 35             screen_ipod_nano_8gb
# 36            screen_netbook_1005ha
# 41         size_asus_netbook_1005ha
# 43       speed_garmin_nuvi_255W_gps
# 48     updates_garmin_nuvi_255W_gps
# 50       voice_garmin_nuvi_255W_gps
#
# ...

# %%
from sklearn.cluster import KMeans

# 3개의 집합으로 군집화 ! 제대로 안됐다! 군집화 개수가 중요하다!!!
km_cluster = KMeans(n_clusters=3, max_iter=10000, random_state=0)
km_cluster.fit(feature_vect)
cluster_label = km_cluster.labels_

# 소속 클러스터를 cluster_label 컬럼으로 할당하고 cluster_label 값으로 정렬
document_df['cluster_label'] = cluster_label
document_df.sort_values(by='cluster_label')
# Out:
#                            filename  \
# 5             buttons_amazon_kindle
# 10    eyesight-issues_amazon_kindle
# 12              fonts_amazon_kindle
# 27              price_amazon_kindle
# 25    performance_honda_accord_2008
# 22        mileage_honda_accord_2008
# 23         navigation_amazon_kindle
# 16    gas_mileage_toyota_camry_2007
# 29        quality_toyota_camry_2007
# 44                   speed_windows7
# 15       free_bestwestern_hotel_sfo
# 21      location_holiday_inn_london
# 14           food_swissotel_chicago
# 13          food_holiday_inn_london
# 6         comfort_honda_accord_2008
# 1    bathroom_bestwestern_hotel_sfo
# 30      rooms_bestwestern_hotel_sfo
# 20   location_bestwestern_hotel_sfo
# 18       interior_toyota_camry_2007
# 24    parking_bestwestern_hotel_sfo
# 31          rooms_swissotel_chicago
# 28         price_holiday_inn_london
# 17       interior_honda_accord_2008
# 7         comfort_toyota_camry_2007
# 37          seats_honda_accord_2008
# ...

# %%
# 군집(Cluster)별 핵심 단어 추출 - KMeans에서는 센터점에서 가까운 단어들! 많이 쓴다규!!! (거리 기반, 가까울 뿐, 관계성이 없다)
cluster_centers = km_cluster.cluster_centers_ # 중심점 찾아서
print('cluster_centers shape :', cluster_centers.shape) # (3, 4610) 3: 군집수, 4610: 단어수, 축의 수, 차원의 수!!! 차원의 저주!!!
print(cluster_centers)

## 아래 함수들은 좋으니까 프로젝트에서 써라~~~잉
# Out:
# cluster_centers shape : (3, 4610)
# [[0.00580396 0.00092552 0.         ... 0.         0.         0.        ]
#  [0.         0.00075846 0.00133071 ... 0.         0.00139731 0.00110157]
#  [0.00966614 0.         0.         ... 0.0088286  0.         0.        ]]

# %%
# 군집별 top n 핵심단어, 그 단어의 중심 위치 상대값, 대상 파일명들을 반환함. 
def get_cluster_details(cluster_model, cluster_data, feature_names, clusters_num, top_n_features=10):
    cluster_details = {}
    
    # cluster_centers array 의 값이 큰 순으로 정렬된 index 값을 반환
    # 군집 중심점(centroid)별 할당된 word 피처들의 거리값이 큰 순으로 값을 구하기 위함.  
    centroid_feature_ordered_ind = cluster_model.cluster_centers_.argsort()[:,::-1]
    
    # 개별 군집별로 iteration하면서 핵심단어, 그 단어의 중심 위치 상대값, 대상 파일명 입력
    for cluster_num in range(clusters_num):
        # 개별 군집별 정보를 담을 데이터 초기화. 
        cluster_details[cluster_num] = {}
        cluster_details[cluster_num]['cluster'] = cluster_num
        
        # cluster_centers_.argsort()[:,::-1] 로 구한 index 를 이용하여 top n 피처 단어를 구함. 
        top_feature_indexes = centroid_feature_ordered_ind[cluster_num, :top_n_features]
        top_features = [ feature_names[ind] for ind in top_feature_indexes ]
        
        # top_feature_indexes를 이용해 해당 피처 단어의 중심 위치 상댓값 구함 
        top_feature_values = cluster_model.cluster_centers_[cluster_num, top_feature_indexes].tolist()
        
        # cluster_details 딕셔너리 객체에 개별 군집별 핵심 단어와 중심위치 상대값, 그리고 해당 파일명 입력
        cluster_details[cluster_num]['top_features'] = top_features
        cluster_details[cluster_num]['top_features_value'] = top_feature_values
        filenames = cluster_data[cluster_data['cluster_label'] == cluster_num]['filename']
        filenames = filenames.values.tolist()
        cluster_details[cluster_num]['filenames'] = filenames
        
    return cluster_details

# %%
def print_cluster_details(cluster_details):
    for cluster_num, cluster_detail in cluster_details.items():
        print('####### Cluster {0}'.format(cluster_num))
        print('Top features:', cluster_detail['top_features'])
        print('Reviews 파일명 :',cluster_detail['filenames'][:7])
        print('==================================================')

# %%
feature_names = tfidf_vect.get_feature_names_out()

cluster_details = get_cluster_details(cluster_model=km_cluster, cluster_data=document_df,\
                                  feature_names=feature_names, clusters_num=3, top_n_features=10 )
print_cluster_details(cluster_details)
# Out:
# ####### Cluster 0
# Top features: ['mileage', 'kindle', 'page', 'gas', 'button', 'gas mileage', 'font', 'performance', 'book', 'eye']
# Reviews 파일명 : ['buttons_amazon_kindle', 'eyesight-issues_amazon_kindle', 'fonts_amazon_kindle', 'gas_mileage_toyota_camry_2007', 'mileage_honda_accord_2008', 'navigation_amazon_kindle', 'performance_honda_accord_2008']
# ...
# ####### Cluster 1
# Top features: ['room', 'hotel', 'service', 'staff', 'interior', 'food', 'location', 'seat', 'comfortable', 'bathroom']
# Reviews 파일명 : ['bathroom_bestwestern_hotel_sfo', 'comfort_honda_accord_2008', 'comfort_toyota_camry_2007', 'food_holiday_inn_london', 'food_swissotel_chicago', 'free_bestwestern_hotel_sfo', 'interior_honda_accord_2008']
# ...
# ####### Cluster 2
# Top features: ['screen', 'battery', 'battery life', 'life', 'keyboard', 'video', 'direction', 'voice', 'map', 'feature']
# ...

# %% [markdown]
# 최종적으로 나중에~ graphRAG로 가야한다. 성능이 좋다. (MS사에서 나온걸로 성능이 좋다. LLM이랑 붙을 듯! 많은 산업들의 자동화에 사용될 것 같다)
# RAG 는 vector: 단어를 vector로 만들어 그래프로 만든것. (단어와 단어를 연결해서...) 연결성이 나온다!!!
# KMeans 는 거리기반, 가까울 수록 묶어주지만, 관계를 파악할 수 없다. 위에 있는 거가 잘 나온다
#
# ## BERTtopic, graphRAG 파이널에서 써봐라!
